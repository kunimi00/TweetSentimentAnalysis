# %%
# Sklearn ML models
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, StratifiedKFold
from sklearn.feature_selection import SelectPercentile, chi2, SelectKBest, mutual_info_classif, RFECV
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
# Python requistes
from collections import Counter
from scipy.sparse import csr_matrix, hstack
from tqdm import tqdm

import numpy as np
import time
import pandas as pd
import os
import re

import matplotlib.pyplot as plt

# %%
# Graph / Visualization
from networkx.drawing.nx_agraph import graphviz_layout
import networkx as nx
import pygraphviz

# %%
# Tweet preprocessor
import preprocessor as p

# %%
# NLTK tokenization / lemmatization
import nltk

from nltk.tokenize import treebank
from nltk.tokenize import word_tokenize
from nltk.tokenize import TweetTokenizer

from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk.corpus.reader import WordListCorpusReader

from nltk.wsd import lesk

from nltk.stem.wordnet import WordNetLemmatizer

import nltk.sentiment

# %%
# Better WSD library
from pywsd.lesk import simple_lesk, original_lesk, cosine_lesk, adapted_lesk
from pywsd import disambiguate
from pywsd.similarity import max_similarity

# %% [markdown]
# ## Tokenization / Negation / Lemmatization / Disambiguation

# %%
file_path = "./dataset/semEval_train_2016/semeval_train_A.txt"
file = open(file_path,"r")
labels = []
tweets = []
for line in file:
    split_string = line.split("\t")
    if len(split_string) == 2:
        tweets.append(split_string[0])
        labels.append(split_string[1])
print(len(tweets))
print(len(labels))
print(tweets[0])
# Out:
# 11692
# 11692
# dec 21st 2012 will be know not as the end of the world but the Baby Boom! #2012shit

# %%
# Negation

replace_dict = {
    "don't": "do not",
    "won't": "will not",
    "didn't": "did not",
    "doesn't": "does not",
    "can't": "can not",
    "couldn't": "could not",
    "isn't": "is not",
    "shouldn't": "should not",
    "wouldn't": "would not",
    "wasn't": "was not",
    "weren't": "were not",
    "haven't": "have not",
    "ain't": "is not",
    "aren't": "are not",
}

def replace_word(text):
    for word in replace_dict:
        if word in text:  # Small first letter
            text = text.replace(word, replace_dict[word])
        elif word[0].title() + word[1:] in text:  # Big first letter
            text = text.replace(word[0].title() + word[1:],
                                replace_dict[word][0].title() + replace_dict[word][1:])

    return text

def neg_tagging(word_list):
    string = ' '.join(word_list)
    transformed = re.sub(r'\b(?:not|never|no)\b[\w\s]+[^\w\s]', 
           lambda match: re.sub(r'(\s+)(\w+)', r'\1NEG_\2', match.group(0)), 
           string,
           flags=re.IGNORECASE)
    
    return transformed

# %%
def negate(word_list):
    negged_sentence = neg_tagging(word_list)
    negged_tokens = negged_sentence.split()

    tokens = []
    token_pair_list = []
    
    for word in negged_tokens:
        negation = False
        if word.startswith('NEG_'):
            negation = True
            word = word[4:]
        token_pair_list.append((word, negation))
        tokens.append(word)
    
    return tokens, token_pair_list

# %% [markdown]
# ### To get better Word Sense Disambiguation, we're only going to pick some of these.
#
# 1.	CC	Coordinating conjunction
# 2.	CD	Cardinal number
# 3.	DT	Determiner
# 4.	EX	Existential there
# 5.	FW	Foreign word
# 6.	IN	Preposition or subordinating conjunction
# 7.	JJ	Adjective
# 8.	JJR	Adjective, comparative
# 9.	JJS	Adjective, superlative
# 10.	LS	List item marker
# 11.	MD	Modal
# 12.	NN	Noun, singular or mass
# 13.	NNS	Noun, plural
# 14.	NNP	Proper noun, singular
# 15.	NNPS	Proper noun, plural
# 16.	PDT	Predeterminer
# 17.	POS	Possessive ending
# 18.	PRP	Personal pronoun
# 19.	PRPS	Possessive pronoun
# 20.	RB	Adverb
# 21.	RBR	Adverb, comparative
# 22.	RBS	Adverb, superlative
# 23.	RP	Particle
# 24.	SYM	Symbol
# 25.	TO	to
# 26.	UH	Interjection
# 27.	VB	Verb, base form
# 28.	VBD	Verb, past tense
# 29.	VBG	Verb, gerund or present participle
# 30.	VBN	Verb, past participle
# 31.	VBP	Verb, non-3rd person singular present
# 32.	VBZ	Verb, 3rd person singular present
# 33.	WDT	Wh-determiner
# 34.	WP	Wh-pronoun
# 35.	WPS	Possessive wh-pronoun
# 36.	WRB	Wh-adverb

# %% [markdown]
# ### (1) Using cosine lesk + Custom selection of POS tags. (for better results)

# %%
for i in range(30):
    
    cleaned_tweet = p.clean(tweets[i])
    replaced_tweet = replace_word(cleaned_tweet)
    replaced_tweet_list = replaced_tweet.split(" ")
    tokens, token_pair_list = negate(replaced_tweet_list)
    token_pos_list = nltk.pos_tag(tokens)
    
    print(tweets[i])
    print(cleaned_tweet)
    print("") 
    print(token_pos_list)
    print("") 
    
    assert(len(token_pos_list) == len(token_pair_list))
    
    score = 0
    for j in range(len(token_pair_list)):
        curr_neg = False
        if token_pair_list[j][1]:
            print("negated : " + token_pair_list[j][0])
            curr_neg = True
            
        ## BETTER SOLUTION (Can hand-engineer FURTHER)
        curr_pos = token_pos_list[j][1]
        if(curr_pos.startswith('N') or curr_pos.startswith('J') or \
           curr_pos.startswith('V')):
            
            ## simple_lesk, original_lesk, cosine_lesk, adapted_lesk --> cosine works best.
            curr_ss = cosine_lesk(cleaned_tweet, token_pair_list[j][0])
            curr_score = 0
            if curr_ss:
                
                ## NOT a good sentiment scoring function
                pos_score = swn.senti_synset(curr_ss.name()).pos_score() 
                neg_score = swn.senti_synset(curr_ss.name()).neg_score()
                curr_score += (pos_score - neg_score)
                if curr_neg:
                    curr_score *= -1
                print("   " + str(token_pair_list[j]) + " -> " + curr_ss.name() + " : " + str(curr_score))
                print("   definition : " + wn.synset(curr_ss.name()).definition())
                print("   pos score : " + str(pos_score))
                print("   neg score : " + str(neg_score))
                print("   obj score : " + str(swn.senti_synset(curr_ss.name()).obj_score()))
                print("")
            score += curr_score
        else:
            continue
    print("  TOTAL score = " + str(score) + " / " + labels[i])
    print("")
# Out:
# dec 21st 2012 will be know not as the end of the world but the Baby Boom! #2012shit
# dec st will be know not as the end of the world but the Baby Boom!
#
# [('dec', 'NN'), ('st', 'NN'), ('will', 'MD'), ('be', 'VB'), ('know', 'JJ'), ('not', 'RB'), ('as', 'IN'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('the', 'DT'), ('world', 'NN'), ('but', 'CC'), ('the', 'DT'), ('Baby', 'NNP'), ('Boom!', 'NNP')]
#
#    ('dec', False) -> december.n.01 : 0.0
#    definition : the last (12th) month of the year
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('be', False) -> beryllium.n.01 : 0.0
#    definition : a light strong brittle grey toxic bivalent metallic element
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('know', False) -> know.n.01 : 0.625
#    definition : the fact of being aware of information that is known to few people
#    pos score : 0.625
#    neg score : 0.0
#    obj score : 0.375
#
# negated : as
# negated : the
# negated : end
#    ('end', True) -> end.n.01 : -0.0
#    definition : either extremity of something that has length
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : of
# negated : the
# negated : world
#    ('world', True) -> universe.n.01 : -0.0
#    definition : everything that exists anywhere
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : but
# negated : the
# negated : Baby
#    ('Baby', True) -> baby.n.01 : -0.0
#    definition : a very young child (birth to 1 year) who has not yet begun to walk or talk
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : Boom!
#   TOTAL score = 0.625 / neutral
#
#
# @MacMiller hate my life, because i can't see you at the roskilde festival on saturday, promise me to come back again, SOON.
# hate my life, because i can't see you at the roskilde festival on saturday, promise me to come back again, SOON.
#
# [('hate', 'VB'), ('my', 'PRP$'), ('life,', 'NN'), ('because', 'IN'), ('i', 'NN'), ('can', 'MD'), ('not', 'RB'), ('see', 'VB'), ('you', 'PRP'), ('at', 'IN'), ('the', 'DT'), ('roskilde', 'NN'), ('festival', 'NN'), ('on', 'IN'), ('saturday,', 'NN'), ('promise', 'NN'), ('me', 'PRP'), ('to', 'TO'), ('come', 'VB'), ('back', 'RB'), ('again,', 'JJ'), ('SOON.', 'NNP')]
#
#    ('hate', False) -> hate.n.01 : -0.25
#    definition : the emotion of intense dislike; a feeling of dislike so strong that it demands action
#    pos score : 0.125
#    neg score : 0.375
#    obj score : 0.5
#
#    ('i', False) -> iodine.n.01 : 0.0
#    definition : a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : see
#    ('see', True) -> see.n.01 : -0.0
#    definition : the seat within a bishop's diocese where his cathedral is located
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : you
# negated : at
# negated : the
# negated : roskilde
# negated : festival
#    ('festival', True) -> festival.n.01 : -0.0
#    definition : a day or period of time set aside for feasting and celebration
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : on
# negated : saturday,
#    ('promise', False) -> promise.n.01 : 0.0
#    definition : a verbal commitment by one person to another agreeing to do (or not to do) something in the future
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('come', False) -> semen.n.01 : 0.0
#    definition : the thick white fluid containing spermatozoa that is ejaculated by the male genital tract
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = -0.25 / negative
#
#
# Checked out Our Lady Peace at Bluesfest tonight and spending the day at the beach for HOPE volleyball tomorrow. Gotta love summer weekends!
# Checked out Our Lady Peace at Bluesfest tonight and spending the day at the beach for HOPE volleyball tomorrow. Gotta love summer weekends!
#
# [('Checked', 'VBN'), ('out', 'RP'), ('Our', 'PRP$'), ('Lady', 'JJ'), ('Peace', 'NN'), ('at', 'IN'), ('Bluesfest', 'NNP'), ('tonight', 'NN'), ('and', 'CC'), ('spending', 'VBG'), ('the', 'DT'), ('day', 'NN'), ('at', 'IN'), ('the', 'DT'), ('beach', 'NN'), ('for', 'IN'), ('HOPE', 'NNP'), ('volleyball', 'NN'), ('tomorrow.', 'NN'), ('Gotta', 'NNP'), ('love', 'VB'), ('summer', 'NN'), ('weekends!', 'NN')]
#
#    ('Checked', False) -> check.v.01 : 0.5
#    definition : examine so as to determine accuracy, quality, or condition
#    pos score : 0.5
#    neg score : 0.0
#    obj score : 0.5
#
#    ('Lady', False) -> lady.n.01 : 0.0
#    definition : a polite name for any woman
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Peace', False) -> peace.n.01 : 0.125
#    definition : the state prevailing during the absence of war
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('tonight', False) -> tonight.n.01 : 0.0
#    definition : the present or immediately coming night
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('spending', False) -> spending.n.01 : 0.0
#    definition : the act of spending or disbursing money
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('day', False) -> day.n.01 : 0.0
#    definition : time for Earth to make a complete rotation on its axis
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('beach', False) -> beach.n.01 : 0.0
#    definition : an area of sand sloping down to the water of a sea or lake
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('HOPE', False) -> hope.n.01 : 0.125
#    definition : a specific instance of feeling hopeful
#    pos score : 0.25
#    neg score : 0.125
#    obj score : 0.625
#
#    ('volleyball', False) -> volleyball.n.01 : 0.0
#    definition : a game in which two teams hit an inflated ball over a high net using their hands
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('love', False) -> love.n.01 : 0.625
#    definition : a strong positive emotion of regard and affection
#    pos score : 0.625
#    neg score : 0.0
#    obj score : 0.375
#
#    ('summer', False) -> summer.n.01 : 0.0
#    definition : the warmest season of the year; in the northern hemisphere it extends from the summer solstice to the autumnal equinox
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 1.375 / positive
#
#
# Hello from the Foundation Trekkers! We're up in chilly Haltwhistle getting ready to trek Hadrian's wall tomorrow :-) http://t.co/MmRnhLAL
# Hello from the Foundation Trekkers! We're up in chilly Haltwhistle getting ready to trek Hadrian's wall tomorrow
#
# [('Hello', 'NNP'), ('from', 'IN'), ('the', 'DT'), ('Foundation', 'NNP'), ('Trekkers!', 'NNP'), ("We're", 'NNP'), ('up', 'RP'), ('in', 'IN'), ('chilly', 'RB'), ('Haltwhistle', 'NNP'), ('getting', 'VBG'), ('ready', 'JJ'), ('to', 'TO'), ('trek', 'VB'), ("Hadrian's", 'NNP'), ('wall', 'NN'), ('tomorrow', 'NN')]
#
#    ('Hello', False) -> hello.n.01 : 0.0
#    definition : an expression of greeting
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Foundation', False) -> foundation.n.01 : 0.0
#    definition : the basis on which something is grounded
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('getting', False) -> acquiring.n.01 : 0.0
#    definition : the act of acquiring something
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('ready', False) -> ready.n.01 : -0.25
#    definition : poised for action
#    pos score : 0.0
#    neg score : 0.25
#    obj score : 0.75
#
#    ('trek', False) -> trek.n.01 : 0.0
#    definition : a journey by ox wagon (especially an organized migration by a group of settlers)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('wall', False) -> wall.n.01 : 0.0
#    definition : an architectural partition with a height and length greater than its thickness; used to divide or enclose an area or to support another structure
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('tomorrow', False) -> tomorrow.n.01 : 0.0
#    definition : the day after today
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = -0.25 / positive
#
#
# Tomorrow we will be proud to play at the Remembrance Service at South Hetton church
# Tomorrow we will be proud to play at the Remembrance Service at South Hetton church
#
# [('Tomorrow', 'NN'), ('we', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('proud', 'JJ'), ('to', 'TO'), ('play', 'VB'), ('at', 'IN'), ('the', 'DT'), ('Remembrance', 'NNP'), ('Service', 'NNP'), ('at', 'IN'), ('South', 'NNP'), ('Hetton', 'NNP'), ('church', 'NN')]
#
#    ('Tomorrow', False) -> tomorrow.n.01 : 0.0
#    definition : the day after today
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('be', False) -> beryllium.n.01 : 0.0
#    definition : a light strong brittle grey toxic bivalent metallic element
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('proud', False) -> proud.a.01 : 0.125
#    definition : feeling self-respect or pleasure in something by which you measure your self-worth; or being a reason for pride
#    pos score : 0.375
#    neg score : 0.25
#    obj score : 0.375
#    ('play', False) -> play.n.01 : 0.0
#    definition : a dramatic work intended for performance by actors on a stage
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Remembrance', False) -> remembrance.n.01 : -0.125
#    definition : the ability to recall past occurrences
#    pos score : 0.0
#    neg score : 0.125
#    obj score : 0.875
#
#    ('Service', False) -> service.n.01 : 0.0
#    definition : work done by one person or group that benefits another
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('South', False) -> south.n.01 : 0.0
#    definition : the region of the United States lying to the south of the Mason-Dixon line
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('church', False) -> church.n.01 : 0.0
#    definition : one of the groups of Christians who have their own beliefs and forms of worship
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / positive
#
#
# Impulsively bought Resident Evil: Operation Raccoon City. Probably won't play it till tomorrow though. Have so much editing to do with 06.
# Impulsively bought Resident Evil: Operation Raccoon City. Probably won't play it till tomorrow though. Have so much editing to do with .
#
# [('Impulsively', 'RB'), ('bought', 'VBD'), ('Resident', 'NNP'), ('Evil:', 'NNP'), ('Operation', 'NNP'), ('Raccoon', 'NNP'), ('City.', 'NNP'), ('Probably', 'NNP'), ('will', 'MD'), ('not', 'RB'), ('play', 'VB'), ('it', 'PRP'), ('till', 'JJ'), ('tomorrow', 'NN'), ('though.', 'NNS'), ('Have', 'VBP'), ('so', 'RB'), ('much', 'JJ'), ('editing', 'NN'), ('to', 'TO'), ('do', 'VB'), ('with', 'IN'), ('.', '.')]
#
#    ('bought', False) -> buy.v.01 : 0.0
#    definition : obtain by purchase; acquire by means of a financial transaction
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Resident', False) -> resident.n.01 : 0.0
#    definition : someone who lives at a particular place for a prolonged period or who was born there
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Operation', False) -> operation.n.01 : 0.0
#    definition : the state of being in effect or being operative
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Raccoon', False) -> raccoon.n.01 : 0.0
#    definition : the fur of the North American racoon
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Probably', False) -> probably.r.01 : 0.0
#    definition : with considerable certainty; without much doubt
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : play
#    ('play', True) -> play.n.01 : -0.0
#    definition : a dramatic work intended for performance by actors on a stage
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : it
# negated : till
#    ('till', True) -> till.n.01 : -0.0
#    definition : unstratified soil deposited by a glacier; consists of sand and clay and gravel and boulders mixed together
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : tomorrow
#    ('tomorrow', True) -> tomorrow.n.01 : -0.0
#    definition : the day after today
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : though.
#    ('Have', False) -> rich_person.n.01 : 0.0
#    definition : a person who possesses great material wealth
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('much', False) -> much.n.01 : 0.0
#    definition : a great amount or extent
#    pos score : 0.125
#    neg score : 0.125
#    obj score : 0.75
#
#    ('editing', False) -> editing.n.01 : 0.0
#    definition : putting something (as a literary work or a legislative bill) into acceptable form
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('do', False) -> bash.n.02 : 0.0
#    definition : an uproarious party
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / negative
#
#
# Just arriving in madrid from Moscow Tomorrow going to HVar, Croatia
# Just arriving in madrid from Moscow Tomorrow going to HVar, Croatia
#
# [('Just', 'RB'), ('arriving', 'VBG'), ('in', 'IN'), ('madrid', 'NN'), ('from', 'IN'), ('Moscow', 'NNP'), ('Tomorrow', 'NNP'), ('going', 'VBG'), ('to', 'TO'), ('HVar,', 'NNP'), ('Croatia', 'NNP')]
#
#    ('arriving', False) -> arrive.v.01 : 0.0
#    definition : reach a destination; arrive by movement or progress
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('madrid', False) -> madrid.n.01 : 0.0
#    definition : the capital and largest city situated centrally in Spain; home of an outstanding art museum
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Moscow', False) -> moscow.n.01 : 0.0
#    definition : a city of central European Russia; formerly capital of both the Soviet Union and Soviet Russia; since 1991 the capital of the Russian Federation
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Tomorrow', False) -> tomorrow.n.01 : 0.0
#    definition : the day after today
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('going', False) -> departure.n.01 : 0.0
#    definition : the act of departing
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Croatia', False) -> croatia.n.01 : 0.0
#    definition : a republic in the western Balkans in south-central Europe in the eastern Adriatic coastal area; formerly part of the Habsburg monarchy and Yugoslavia; became independent in 1991
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / neutral
#
#
# Just packing for a weekend in Liverpool and the small matter of a marathon on Sunday. First up though...Blackpool Illuminations!
# Just packing for a weekend in Liverpool and the small matter of a marathon on Sunday. First up though...Blackpool Illuminations!
#
# [('Just', 'RB'), ('packing', 'VBG'), ('for', 'IN'), ('a', 'DT'), ('weekend', 'NN'), ('in', 'IN'), ('Liverpool', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('small', 'JJ'), ('matter', 'NN'), ('of', 'IN'), ('a', 'DT'), ('marathon', 'NN'), ('on', 'IN'), ('Sunday.', 'NNP'), ('First', 'NNP'), ('up', 'RP'), ('though...Blackpool', 'NN'), ('Illuminations!', 'NNP')]
#
#    ('packing', False) -> packing_material.n.01 : 0.0
#    definition : any material used especially to protect something
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('weekend', False) -> weekend.n.01 : 0.0
#    definition : a time period usually extending from Friday night through Sunday; more loosely defined as any period of successive days including one and only one Sunday
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Liverpool', False) -> liverpool.n.01 : 0.0
#    definition : a large city in northwestern England; its port is the country's major outlet for industrial exports
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('small', False) -> small.n.01 : 0.0
#    definition : the slender part of the back
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('matter', False) -> matter.n.01 : -0.125
#    definition : a vaguely specified concern
#    pos score : 0.125
#    neg score : 0.25
#    obj score : 0.625
#
#    ('marathon', False) -> marathon.n.01 : 0.0
#    definition : any long and arduous undertaking
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('First', False) -> first.n.01 : 0.0
#    definition : the first or highest in an ordering or series
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = -0.125 / neutral
#
#
# Your plans of attending the Great Yorkshire Show may have been washed out because of the weather, so how about... http://t.co/fEsAtbk8
# Your plans of attending the Great Yorkshire Show may have been washed out because of the weather, so how about...
#
# [('Your', 'PRP$'), ('plans', 'NNS'), ('of', 'IN'), ('attending', 'VBG'), ('the', 'DT'), ('Great', 'NNP'), ('Yorkshire', 'NNP'), ('Show', 'NNP'), ('may', 'MD'), ('have', 'VB'), ('been', 'VBN'), ('washed', 'VBN'), ('out', 'RP'), ('because', 'IN'), ('of', 'IN'), ('the', 'DT'), ('weather,', 'NN'), ('so', 'IN'), ('how', 'WRB'), ('about...', 'JJ')]
#
#    ('plans', False) -> plan.n.01 : 0.0
#    definition : a series of steps to be carried out or goals to be accomplished
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('attending', False) -> attention.n.01 : 0.0
#    definition : the process whereby a person concentrates on some features of the environment to the (relative) exclusion of others
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Great', False) -> great.n.01 : 0.0
#    definition : a person who has achieved distinction and honor in some field
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Yorkshire', False) -> yorkshire.n.01 : 0.0
#    definition : a former large county in northern England; in 1974 it was divided into three smaller counties
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#    ('Show', False) -> show.n.01 : 0.0
#    definition : the act of publicly exhibiting or entertaining
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('have', False) -> rich_person.n.01 : 0.0
#    definition : a person who possesses great material wealth
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('been', False) -> be.v.01 : 0.125
#    definition : have the quality of being; (copula, used with an adjective or a predicate noun)
#    pos score : 0.25
#    neg score : 0.125
#    obj score : 0.625
#
#    ('washed', False) -> wash.v.01 : -0.125
#    definition : clean with some chemical process
#    pos score : 0.0
#    neg score : 0.125
#    obj score : 0.875
#
#   TOTAL score = 0.0 / negative
#
#
# By the end of today I will have worked 14hrs, done my workout and attended part of Hot Jam. Hitting the ground running this Monday.
# By the end of today I will have worked hrs, done my workout and attended part of Hot Jam. Hitting the ground running this Monday.
#
# [('By', 'IN'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('today', 'NN'), ('I', 'PRP'), ('will', 'MD'), ('have', 'VB'), ('worked', 'VBN'), ('hrs,', 'JJ'), ('done', 'VBN'), ('my', 'PRP$'), ('workout', 'NN'), ('and', 'CC'), ('attended', 'VBD'), ('part', 'NN'), ('of', 'IN'), ('Hot', 'NNP'), ('Jam.', 'NNP'), ('Hitting', 'VBG'), ('the', 'DT'), ('ground', 'NN'), ('running', 'VBG'), ('this', 'DT'), ('Monday.', 'NN')]
#
#    ('end', False) -> end.n.01 : 0.0
#    definition : either extremity of something that has length
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('today', False) -> today.n.01 : 0.125
#    definition : the present time or age
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('have', False) -> rich_person.n.01 : 0.0
#    definition : a person who possesses great material wealth
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('worked', False) -> work.v.01 : 0.0
#    definition : exert oneself by doing mental or physical work for a purpose or out of necessity
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('done', False) -> make.v.01 : 0.0
#    definition : engage in
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('workout', False) -> exercise.n.01 : 0.0
#    definition : the activity of exerting your muscles in various ways to keep fit
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('attended', False) -> attend.v.01 : 0.0
#    definition : be present at (meetings, church services, university), etc.
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('part', False) -> part.n.01 : 0.0
#    definition : something determined in relation to something that includes it
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Hot', False) -> hot.a.01 : 0.0
#    definition : used of physical heat; having a high or higher than desirable temperature or giving off heat or feeling or causing a sensation of heat or burning
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Hitting', False) -> hit.n.02 : 0.0
#    definition : the act of contacting one thing with another
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('ground', False) -> land.n.04 : 0.0
#    definition : the solid part of the earth's surface
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('running', False) -> run.n.05 : 0.0
#    definition : (American football) a play in which a player attempts to carry the ball through or past the opposing team
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.125 / neutral
#
#
# Check out this weeks the @SixersBBL Scoop column looking back on Sat Nights win over the Thunder! http://t.co/lRto77al #smashemsixers #BBL02
# Check out this weeks the Scoop column looking back on Sat Nights win over the Thunder!
#
# [('Check', 'VB'), ('out', 'RP'), ('this', 'DT'), ('weeks', 'NNS'), ('the', 'DT'), ('Scoop', 'NNP'), ('column', 'NN'), ('looking', 'VBG'), ('back', 'RB'), ('on', 'IN'), ('Sat', 'NNP'), ('Nights', 'NNP'), ('win', 'NN'), ('over', 'IN'), ('the', 'DT'), ('Thunder!', 'NNP')]
#
#    ('Check', False) -> check.n.01 : 0.0
#    definition : a written order directing a bank to pay money
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('weeks', False) -> week.n.01 : 0.0
#    definition : any period of seven consecutive days
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Scoop', False) -> scoop.n.01 : 0.0
#    definition : the quantity a scoop will hold
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('column', False) -> column.n.01 : 0.0
#    definition : a line of units following one after another
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('looking', False) -> look.n.02 : 0.125
#    definition : the act of directing the eyes toward something and perceiving it visually
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('Sat', False) -> saturday.n.01 : 0.0
#    definition : the seventh and last day of the week; observed as the Sabbath by Jews and some Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Nights', False) -> night.n.01 : 0.0
#    definition : the time after sunset and before sunrise while it is dark outside
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('win', False) -> win.n.01 : 0.125
#    definition : a victory (as in a race or other competition)
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#   TOTAL score = 0.25 / neutral
#
#
# Three day weekend a head. Tonight Grand Bend forracing, Saturday Grand Bend with the inlaws more racing. Sunday first #Sting game for us.
# Three day weekend a head. Tonight Grand Bend forracing, Saturday Grand Bend with the inlaws more racing. Sunday first game for us.
#
# [('Three', 'CD'), ('day', 'NN'), ('weekend', 'NN'), ('a', 'DT'), ('head.', 'NN'), ('Tonight', 'NNP'), ('Grand', 'NNP'), ('Bend', 'NNP'), ('forracing,', 'NN'), ('Saturday', 'NNP'), ('Grand', 'NNP'), ('Bend', 'NNP'), ('with', 'IN'), ('the', 'DT'), ('inlaws', 'NNS'), ('more', 'RBR'), ('racing.', 'NNS'), ('Sunday', 'NNP'), ('first', 'RB'), ('game', 'NN'), ('for', 'IN'), ('us.', 'NN')]
#
#    ('day', False) -> day.n.01 : 0.0
#    definition : time for Earth to make a complete rotation on its axis
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('weekend', False) -> weekend.n.01 : 0.0
#    definition : a time period usually extending from Friday night through Sunday; more loosely defined as any period of successive days including one and only one Sunday
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Tonight', False) -> tonight.n.01 : 0.0
#    definition : the present or immediately coming night
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Grand', False) -> thousand.n.01 : 0.0
#    definition : the cardinal number that is the product of 10 and 100
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Bend', False) -> bend.n.01 : 0.0
#    definition : a circular segment of a curve
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Saturday', False) -> saturday.n.01 : 0.0
#    definition : the seventh and last day of the week; observed as the Sabbath by Jews and some Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Grand', False) -> thousand.n.01 : 0.0
#    definition : the cardinal number that is the product of 10 and 100
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Bend', False) -> bend.n.01 : 0.0
#    definition : a circular segment of a curve
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Sunday', False) -> sunday.n.01 : 0.0
#    definition : first day of the week; observed as a day of rest and worship by most Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('game', False) -> game.n.01 : 0.0
#    definition : a contest with rules to determine a winner
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / positive
#
#
# Have you been inspired by Ironman Wales? Why not give triathlon a go by taking part in the Fishguard Go Tri on Sunday. http://t.co/lDfNW2fG
# Have you been inspired by Ironman Wales? Why not give triathlon a go by taking part in the Fishguard Go Tri on Sunday.
#
# [('Have', 'VBP'), ('you', 'PRP'), ('been', 'VBN'), ('inspired', 'VBN'), ('by', 'IN'), ('Ironman', 'NNP'), ('Wales?', 'NNP'), ('Why', 'WRB'), ('not', 'RB'), ('give', 'VB'), ('triathlon', 'NN'), ('a', 'DT'), ('go', 'NN'), ('by', 'IN'), ('taking', 'VBG'), ('part', 'NN'), ('in', 'IN'), ('the', 'DT'), ('Fishguard', 'NNP'), ('Go', 'NNP'), ('Tri', 'NNP'), ('on', 'IN'), ('Sunday.', 'NNP')]
#
#    ('Have', False) -> rich_person.n.01 : 0.0
#    definition : a person who possesses great material wealth
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#    ('been', False) -> be.v.01 : 0.125
#    definition : have the quality of being; (copula, used with an adjective or a predicate noun)
#    pos score : 0.25
#    neg score : 0.125
#    obj score : 0.625
#
#    ('inspired', False) -> inspire.v.01 : 0.125
#    definition : heighten or intensify
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('Ironman', False) -> iron_man.n.01 : 0.25
#    definition : a strong man of exceptional physical endurance
#    pos score : 0.25
#    neg score : 0.0
#    obj score : 0.75
#
# negated : give
#    ('give', True) -> give.n.01 : -0.0
#    definition : the elasticity of something that can be stretched and returns to its original length
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : triathlon
# negated : a
# negated : go
#    ('go', True) -> go.n.01 : -0.0
#    definition : a time for working (after which you will be relieved by someone else)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : by
# negated : taking
#    ('taking', True) -> pickings.n.01 : -0.0
#    definition : the act of someone who picks up or takes something
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : part
#    ('part', True) -> part.n.01 : -0.0
#    definition : something determined in relation to something that includes it
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : in
# negated : the
# negated : Fishguard
# negated : Go
#    ('Go', True) -> go.n.01 : -0.0
#    definition : a time for working (after which you will be relieved by someone else)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : Tri
# negated : on
# negated : Sunday.
#   TOTAL score = 0.5 / positive
#
#
# I've found lyrics of Kiryu - Kaika!!! YES!!! but I've sat down to listen a song and write it already...))
# I've found lyrics of Kiryu - Kaika!!! YES!!! but I've sat down to listen a song and write it already...))
#
# [("I've", 'NNP'), ('found', 'VBD'), ('lyrics', 'NNS'), ('of', 'IN'), ('Kiryu', 'NNP'), ('-', ':'), ('Kaika!!!', 'NNP'), ('YES!!!', 'NNP'), ('but', 'CC'), ("I've", 'NNP'), ('sat', 'VBD'), ('down', 'RB'), ('to', 'TO'), ('listen', 'VB'), ('a', 'DT'), ('song', 'NN'), ('and', 'CC'), ('write', 'VB'), ('it', 'PRP'), ('already...))', 'RP')]
#
#    ('found', False) -> found.n.01 : 0.0
#    definition : food and lodging provided in addition to money
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('lyrics', False) -> lyric.n.01 : 0.0
#    definition : the text of a popular song or musical-comedy number
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('sat', False) -> saturday.n.01 : 0.0
#    definition : the seventh and last day of the week; observed as the Sabbath by Jews and some Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('listen', False) -> listen.v.01 : 0.0
#    definition : hear with intention
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('song', False) -> song.n.01 : 0.0
#    definition : a short musical composition with words
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('write', False) -> write.v.01 : 0.0
#    definition : produce a literary work
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / positive
#
#
# Jonathan Kozol is the leading author on educational advocacy and social equality. He will be on campus Wednesday,... http://t.co/nteU8d3w
# Jonathan Kozol is the leading author on educational advocacy and social equality. He will be on campus Wednesday,...
#
# [('Jonathan', 'NNP'), ('Kozol', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('leading', 'VBG'), ('author', 'NN'), ('on', 'IN'), ('educational', 'JJ'), ('advocacy', 'NN'), ('and', 'CC'), ('social', 'JJ'), ('equality.', 'NN'), ('He', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('on', 'IN'), ('campus', 'NN'), ('Wednesday,...', 'NNP')]
#
#    ('Jonathan', False) -> jonathan.n.01 : 0.0
#    definition : red late-ripening apple; primarily eaten raw
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('is', False) -> be.v.01 : 0.125
#    definition : have the quality of being; (copula, used with an adjective or a predicate noun)
#    pos score : 0.25
#    neg score : 0.125
#    obj score : 0.625
#
#    ('leading', False) -> lead.n.14 : 0.0
#    definition : thin strip of metal used to separate lines of type in printing
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('author', False) -> writer.n.01 : 0.0
#    definition : writes (books or stories or articles or the like) professionally (for pay)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('educational', False) -> educational.a.01 : 0.0
#    definition : relating to the process of education
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('advocacy', False) -> advocacy.n.01 : 0.0
#    definition : active support of an idea or cause etc.; especially the act of pleading or arguing for something
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('social', False) -> sociable.n.01 : 0.0
#    definition : a party of people assembled to promote sociability and communal activity
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('be', False) -> beryllium.n.01 : 0.0
#    definition : a light strong brittle grey toxic bivalent metallic element
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('campus', False) -> campus.n.01 : 0.0
#    definition : a field on which the buildings of a university are situated
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.125 / neutral
#
#
# @nurinqistinaa @hannahban4na That's the 1st.2nd: Nadia &amp; Mysa about Mysa break dgn Adam. 3rd: this bullshit thingy -.-
# That's the st.2nd: Nadia &amp; Mysa about Mysa break dgn Adam. rd: this bullshit thingy -.-
#
# [("That's", 'IN'), ('the', 'DT'), ('st.2nd:', 'JJ'), ('Nadia', 'NNP'), ('&amp;', 'NNP'), ('Mysa', 'NNP'), ('about', 'IN'), ('Mysa', 'NNP'), ('break', 'NN'), ('dgn', 'NN'), ('Adam.', 'NNP'), ('rd:', 'NN'), ('this', 'DT'), ('bullshit', 'NN'), ('thingy', 'VBZ'), ('-.-', 'NN')]
#
#    ('break', False) -> interruption.n.02 : 0.0
#    definition : some abrupt occurrence that interrupts an ongoing activity
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('bullshit', False) -> bullshit.n.01 : -0.375
#    definition : obscene words for unacceptable behavior
#    pos score : 0.0
#    neg score : 0.375
#    obj score : 0.625
#
#   TOTAL score = -0.375 / negative
#
#
# Thanks to all those who joined UYSA and the University of Utah in celebrating Youth Soccer Month last Saturday,... http://t.co/39jQBGV8
# Thanks to all those who joined UYSA and the University of Utah in celebrating Youth Soccer Month last Saturday,...
#
# [('Thanks', 'NNS'), ('to', 'TO'), ('all', 'PDT'), ('those', 'DT'), ('who', 'WP'), ('joined', 'VBD'), ('UYSA', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('University', 'NNP'), ('of', 'IN'), ('Utah', 'NNP'), ('in', 'IN'), ('celebrating', 'VBG'), ('Youth', 'NNP'), ('Soccer', 'NNP'), ('Month', 'NNP'), ('last', 'JJ'), ('Saturday,...', 'NNP')]
#
#    ('Thanks', False) -> thanks.n.01 : 0.125
#    definition : an acknowledgment of appreciation
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('joined', False) -> join.v.01 : 0.0
#    definition : become part of; become a member of a group or organization
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('University', False) -> university.n.01 : 0.0
#    definition : the body of faculty and students at a university
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Utah', False) -> utah.n.01 : 0.0
#    definition : a state in the western United States; settled in 1847 by Mormons led by Brigham Young
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('celebrating', False) -> observe.v.06 : 0.0
#    definition : behave as expected during of holidays or rites
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Youth', False) -> young_person.n.01 : 0.0
#    definition : a young person (especially a young man or boy)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Soccer', False) -> soccer.n.01 : 0.0
#    definition : a football game in which two teams of 11 players try to kick or head a ball into the opponents' goal
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Month', False) -> calendar_month.n.01 : 0.0
#    definition : one of the twelve divisions of the calendar year
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('last', False) -> stopping_point.n.01 : 0.0
#    definition : the temporal end; the concluding time
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.125 / positive
#
#
# @pkollar Well it was either that or watch you play Raccoon City, so.. I think I may have won?
# Well it was either that or watch you play Raccoon City, so.. I think I may have won?
#
# [('Well', 'IN'), ('it', 'PRP'), ('was', 'VBD'), ('either', 'CC'), ('that', 'IN'), ('or', 'CC'), ('watch', 'VB'), ('you', 'PRP'), ('play', 'VB'), ('Raccoon', 'NNP'), ('City,', 'NNP'), ('so..', 'VBD'), ('I', 'PRP'), ('think', 'VBP'), ('I', 'PRP'), ('may', 'MD'), ('have', 'VB'), ('won?', 'NN')]
#
#    ('was', False) -> washington.n.02 : 0.0
#    definition : a state in northwestern United States on the Pacific
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('watch', False) -> watch.n.01 : 0.0
#    definition : a small portable timepiece
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('play', False) -> play.n.01 : 0.0
#    definition : a dramatic work intended for performance by actors on a stage
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Raccoon', False) -> raccoon.n.01 : 0.0
#    definition : the fur of the North American racoon
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('think', False) -> think.n.01 : 0.0
#    definition : an instance of deliberate thinking
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('have', False) -> rich_person.n.01 : 0.0
#    definition : a person who possesses great material wealth
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / positive
#
#
# Day 1 at the SoCal College Fair @ Pomona Fairplex--1st person to get to our booth &amp; say "your story matters" wins something special! #doit
# Day at the SoCal College Fair Pomona Fairplex--1st person to get to our booth &amp; say "your story matters" wins something special!
#
# [('Day', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('SoCal', 'NNP'), ('College', 'NNP'), ('Fair', 'NNP'), ('Pomona', 'NNP'), ('Fairplex--1st', 'NNP'), ('person', 'NN'), ('to', 'TO'), ('get', 'VB'), ('to', 'TO'), ('our', 'PRP$'), ('booth', 'JJ'), ('&amp;', 'NNP'), ('say', 'VBP'), ('"your', 'JJ'), ('story', 'NN'), ('matters"', 'NN'), ('wins', 'VBZ'), ('something', 'NN'), ('special!', 'NN')]
#
#    ('Day', False) -> day.n.01 : 0.0
#    definition : time for Earth to make a complete rotation on its axis
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('College', False) -> college.n.01 : 0.0
#    definition : the body of faculty and students of a college
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Fair', False) -> carnival.n.03 : 0.0
#    definition : a traveling show; having sideshows and rides and games of skill etc.
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('person', False) -> person.n.01 : 0.0
#    definition : a human being
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('get', False) -> get.n.01 : 0.0
#    definition : a return on a shot that seemed impossible to reach and would normally have resulted in a point for the opponent
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('booth', False) -> booth.n.01 : 0.125
#    definition : a table (in a restaurant or bar) surrounded by two high-backed benches
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('say', False) -> say.n.01 : 0.125
#    definition : the chance to speak
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('story', False) -> narrative.n.01 : 0.0
#    definition : a message that tells the particulars of an act or occurrence or course of events; presented in writing or drama or cinema or as a radio or television program
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('wins', False) -> win.n.01 : 0.125
#    definition : a victory (as in a race or other competition)
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#   TOTAL score = 0.375 / positive
#
#
# De La Soul's First Serve project with Live Band debuts this Thu 18th in Meeting House Square, ONRA supports on MPC  http://t.co/DN2SfycQ!!!
# De La Soul's First Serve project with Live Band debuts this Thu th in Meeting House Square, ONRA supports on MPC !!!
#
# [('De', 'NNP'), ('La', 'NNP'), ("Soul's", 'NNP'), ('First', 'NNP'), ('Serve', 'NNP'), ('project', 'NN'), ('with', 'IN'), ('Live', 'NNP'), ('Band', 'NNP'), ('debuts', 'VBZ'), ('this', 'DT'), ('Thu', 'NNP'), ('th', 'NN'), ('in', 'IN'), ('Meeting', 'NNP'), ('House', 'NNP'), ('Square,', 'NNP'), ('ONRA', 'NNP'), ('supports', 'VBZ'), ('on', 'IN'), ('MPC', 'NNP'), ('!!!', 'NN')]
#
#    ('De', False) -> delaware.n.04 : 0.0
#    definition : a Mid-Atlantic state; one of the original 13 colonies
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('La', False) -> lanthanum.n.01 : 0.0
#    definition : a white soft metallic element that tarnishes readily; occurs in rare earth minerals and is usually classified as a rare earth
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('First', False) -> first.n.01 : 0.0
#    definition : the first or highest in an ordering or series
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Serve', False) -> serve.n.01 : 0.0
#    definition : (sports) a stroke that puts the ball in play
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('project', False) -> undertaking.n.01 : 0.0
#    definition : any piece of work that is undertaken or attempted
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Live', False) -> populate.v.01 : 0.0
#    definition : inhabit or live in; be an inhabitant of
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Band', False) -> set.n.05 : 0.0
#    definition : an unofficial association of people or groups
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('debuts', False) -> introduction.n.01 : 0.0
#    definition : the act of beginning something new
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('th', False) -> thursday.n.01 : 0.0
#    definition : the fifth day of the week; the fourth working day
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Meeting', False) -> meeting.n.01 : 0.0
#    definition : a formally arranged gathering
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('House', False) -> house.n.01 : 0.0
#    definition : a dwelling that serves as living quarters for one or more families
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('supports', False) -> support.n.01 : 0.0
#    definition : the activity of providing for or maintaining by supplying with money or necessities
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / neutral
#
#
# @keccles653 I just googled it haha Catelynn and Tyler met first and butch and April have been married but they got divorced
# I just googled it haha Catelynn and Tyler met first and butch and April have been married but they got divorced
#
# [('I', 'PRP'), ('just', 'RB'), ('googled', 'VBD'), ('it', 'PRP'), ('haha', 'VBZ'), ('Catelynn', 'NNP'), ('and', 'CC'), ('Tyler', 'NNP'), ('met', 'VBD'), ('first', 'JJ'), ('and', 'CC'), ('butch', 'NN'), ('and', 'CC'), ('April', 'NNP'), ('have', 'VBP'), ('been', 'VBN'), ('married', 'VBN'), ('but', 'CC'), ('they', 'PRP'), ('got', 'VBD'), ('divorced', 'VBN')]
#
#    ('googled', False) -> google.v.01 : -0.125
#    definition : search the internet (for information) using the Google search engine
#    pos score : 0.125
#    neg score : 0.25
#    obj score : 0.625
#
#    ('Tyler', False) -> tyler.n.01 : 0.0
#    definition : elected vice president and became the 10th President of the United States when Harrison died (1790-1862)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('met', False) -> meet.v.01 : 0.0
#    definition : come together
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('first', False) -> first.n.01 : 0.0
#    definition : the first or highest in an ordering or series
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('butch', False) -> butch.n.01 : -0.375
#    definition : (slang) offensive term for a lesbian who is noticeably masculine
#    pos score : 0.0
#    neg score : 0.375
#    obj score : 0.625
#
#    ('April', False) -> april.n.01 : 0.0
#    definition : the month following March and preceding May
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('have', False) -> rich_person.n.01 : 0.0
#    definition : a person who possesses great material wealth
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('been', False) -> be.v.01 : 0.125
#    definition : have the quality of being; (copula, used with an adjective or a predicate noun)
#    pos score : 0.25
#    neg score : 0.125
#    obj score : 0.625
#
#    ('married', False) -> married.n.01 : 0.0
#    definition : a person who is married
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('got', False) -> get.v.01 : 0.125
#    definition : come into the possession of something concrete or abstract
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('divorced', False) -> disassociate.v.01 : 0.0
#    definition : part; cease or break association with
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = -0.25 / neutral
# Anybody going to that 4th of July pool party in Knollwood?
# Anybody going to that th of July pool party in Knollwood?
#
# [('Anybody', 'NN'), ('going', 'VBG'), ('to', 'TO'), ('that', 'DT'), ('th', 'NN'), ('of', 'IN'), ('July', 'NNP'), ('pool', 'NN'), ('party', 'NN'), ('in', 'IN'), ('Knollwood?', 'NNP')]
#
#    ('going', False) -> departure.n.01 : 0.0
#    definition : the act of departing
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('th', False) -> thursday.n.01 : 0.0
#    definition : the fifth day of the week; the fourth working day
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('July', False) -> july.n.01 : 0.0
#    definition : the month following June and preceding August
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('pool', False) -> pool.n.01 : 0.0
#    definition : an excavation that is (usually) filled with water
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('party', False) -> party.n.01 : 0.0
#    definition : an organization to gain political power
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / neutral
#
#
# Team CK vs Demolition on November 17th at the American Legion Post 80, Main St. in Binghamton NY. Get your tickets now! http://t.co/BieEefZD
# Team CK vs Demolition on November th at the American Legion Post , Main St. in Binghamton NY. Get your tickets now!
#
# [('Team', 'NN'), ('CK', 'NNP'), ('vs', 'NN'), ('Demolition', 'NNP'), ('on', 'IN'), ('November', 'NNP'), ('th', 'NN'), ('at', 'IN'), ('the', 'DT'), ('American', 'NNP'), ('Legion', 'NNP'), ('Post', 'NNP'), (',', ','), ('Main', 'NNP'), ('St.', 'NNP'), ('in', 'IN'), ('Binghamton', 'NNP'), ('NY.', 'NNP'), ('Get', 'NNP'), ('your', 'PRP$'), ('tickets', 'NNS'), ('now!', 'VBP')]
#
#    ('Team', False) -> team.n.01 : 0.0
#    definition : a cooperative unit (especially in sports)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('vs', False) -> volt.n.01 : 0.0
#    definition : a unit of potential equal to the potential difference between two points on a conductor carrying a current of 1 ampere when the power dissipated between the two points is 1 watt; equivalent to the potential difference across a resistance of 1 ohm when 1 ampere of current flows through it
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Demolition', False) -> destruction.n.02 : 0.0
#    definition : an event (or the result of an event) that completely destroys something
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('November', False) -> november.n.01 : 0.0
#    definition : the month following October and preceding December
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('th', False) -> thursday.n.01 : 0.0
#    definition : the fifth day of the week; the fourth working day
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('American', False) -> american.n.01 : 0.0
#    definition : a native or inhabitant of the United States
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Legion', False) -> host.n.05 : 0.0
#    definition : archaic terms for army
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Post', False) -> post.n.01 : 0.0
#    definition : the position where someone (as a guard or sentry) stands or is assigned to stand
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Main', False) -> main.n.01 : 0.0
#    definition : any very large body of (salt) water
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Binghamton', False) -> binghamton.n.01 : 0.0
#    definition : a city in south central New York near the border with Pennsylvania
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Get', False) -> get.n.01 : 0.0
#    definition : a return on a shot that seemed impossible to reach and would normally have resulted in a point for the opponent
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('tickets', False) -> ticket.n.01 : 0.0
#    definition : a commercial document showing that the holder is entitled to something (as to ride on public transportation or to enter a public entertainment)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / positive
#
#
# @GMA My daughter @jordynking17 will be 14 on December 17th! We r going to see Buddy @ The Kirby Center in WB on December 14th. So excited!
# My daughter will be on December th! We r going to see Buddy The Kirby Center in WB on December th. So excited!
#
# [('My', 'PRP$'), ('daughter', 'NN'), ('will', 'MD'), ('be', 'VB'), ('on', 'IN'), ('December', 'NNP'), ('th!', 'NN'), ('We', 'PRP'), ('r', 'VBP'), ('going', 'VBG'), ('to', 'TO'), ('see', 'VB'), ('Buddy', 'NNP'), ('The', 'DT'), ('Kirby', 'NNP'), ('Center', 'NNP'), ('in', 'IN'), ('WB', 'NNP'), ('on', 'IN'), ('December', 'NNP'), ('th.', 'NN'), ('So', 'NNP'), ('excited!', 'NN')]
#
#    ('daughter', False) -> daughter.n.01 : 0.0
#    definition : a female human offspring
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('be', False) -> beryllium.n.01 : 0.0
#    definition : a light strong brittle grey toxic bivalent metallic element
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('December', False) -> december.n.01 : 0.0
#    definition : the last (12th) month of the year
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('r', False) -> roentgen.n.01 : 0.0
#    definition : a unit of radiation exposure; the dose of ionizing radiation that will produce 1 electrostatic unit of electricity in 1 cc of dry air
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('going', False) -> departure.n.01 : 0.0
#    definition : the act of departing
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('see', False) -> see.n.01 : 0.0
#    definition : the seat within a bishop's diocese where his cathedral is located
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Buddy', False) -> buddy.n.01 : 0.125
#    definition : a close friend who accompanies his buddies in their activities
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('Center', False) -> center.n.01 : 0.0
#    definition : an area that is approximately central within some larger region
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('WB', False) -> weber.n.01 : 0.0
#    definition : a unit of magnetic flux equal to 100,000,000 maxwells
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('December', False) -> december.n.01 : 0.0
#    definition : the last (12th) month of the year
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('So', False) -> sol.n.03 : 0.0
#    definition : the syllable naming the fifth (dominant) note of any musical scale in solmization
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.125 / positive
#
#
# #tunewiki "How to See the Sun Rise" by Ben Sollee http://t.co/NGmKGoS1
# "How to See the Sun Rise" by Ben Sollee
#
# [('"How', 'NN'), ('to', 'TO'), ('See', 'VB'), ('the', 'DT'), ('Sun', 'NNP'), ('Rise"', 'NNP'), ('by', 'IN'), ('Ben', 'NNP'), ('Sollee', 'NNP')]
#
#    ('See', False) -> see.n.01 : 0.0
#    definition : the seat within a bishop's diocese where his cathedral is located
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Sun', False) -> sun.n.01 : 0.0
#    definition : the star that is the source of light and heat for the planets in the solar system
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Ben', False) -> ben.n.01 : 0.125
#    definition : a mountain or tall hill
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#   TOTAL score = 0.125 / neutral
#
#
# Morning!!!! Soundset was popin and hot as a tity but time to waken bake easy the sun burn haaa
# Morning!!!! Soundset was popin and hot as a tity but time to waken bake easy the sun burn haaa
#
# [('Morning!!!!', 'NNP'), ('Soundset', 'NNP'), ('was', 'VBD'), ('popin', 'JJ'), ('and', 'CC'), ('hot', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('tity', 'NN'), ('but', 'CC'), ('time', 'NN'), ('to', 'TO'), ('waken', 'VB'), ('bake', 'NN'), ('easy', 'IN'), ('the', 'DT'), ('sun', 'NN'), ('burn', 'NN'), ('haaa', 'NN')]
#
#    ('was', False) -> washington.n.02 : 0.0
#    definition : a state in northwestern United States on the Pacific
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('hot', False) -> hot.a.01 : 0.0
#    definition : used of physical heat; having a high or higher than desirable temperature or giving off heat or feeling or causing a sensation of heat or burning
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('tity', False) -> titi.n.01 : 0.0
#    definition : tree of low-lying coastal areas of southeastern United States having glossy leaves and racemes of fragrant white flowers
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('time', False) -> time.n.01 : 0.0
#    definition : an instance or single occasion for some event
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('waken', False) -> awaken.v.01 : 0.375
#    definition : cause to become awake or conscious
#    pos score : 0.375
#    neg score : 0.0
#    obj score : 0.625
#
#    ('bake', False) -> bake.v.01 : 0.0
#    definition : cook and make edible by putting in a hot oven
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('sun', False) -> sun.n.01 : 0.0
#    definition : the star that is the source of light and heat for the planets in the solar system
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('burn', False) -> burn.n.01 : -0.625
#    definition : pain that feels hot as if it were on fire
#    pos score : 0.0
#    neg score : 0.625
#    obj score : 0.375
#
#   TOTAL score = -0.25 / positive
#
#
# Teddy Bear Toss, a Brad Mills goal and more fun from Maverik Center in a tough loss Friday. See you tomorrow at 7! http://t.co/ytoBfqfW
# Teddy Bear Toss, a Brad Mills goal and more fun from Maverik Center in a tough loss Friday. See you tomorrow at !
#
# [('Teddy', 'NNP'), ('Bear', 'NNP'), ('Toss,', 'NNP'), ('a', 'DT'), ('Brad', 'NNP'), ('Mills', 'NNP'), ('goal', 'NN'), ('and', 'CC'), ('more', 'JJR'), ('fun', 'NN'), ('from', 'IN'), ('Maverik', 'NNP'), ('Center', 'NNP'), ('in', 'IN'), ('a', 'DT'), ('tough', 'JJ'), ('loss', 'NN'), ('Friday.', 'NNP'), ('See', 'NNP'), ('you', 'PRP'), ('tomorrow', 'NN'), ('at', 'IN'), ('!', '.')]
#
#    ('Teddy', False) -> teddy.n.01 : 0.0
#    definition : plaything consisting of a child's toy bear (usually plush and stuffed with soft materials)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Bear', False) -> bear.n.01 : 0.0
#    definition : massive plantigrade carnivorous or omnivorous mammals with long shaggy coats and strong claws
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Brad', False) -> brad.n.01 : 0.0
#    definition : a small nail
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Mills', False) -> mills.n.01 : 0.0
#    definition : United States architect who was the presidentially appointed architect of Washington D.C. (1781-1855)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('goal', False) -> goal.n.01 : 0.0
#    definition : the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('more', False) -> more.n.01 : 0.0
#    definition : English statesman who opposed Henry VIII's divorce from Catherine of Aragon and was imprisoned and beheaded; recalled for his concept of Utopia, the ideal state
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('fun', False) -> fun.n.01 : 0.375
#    definition : activities that are enjoyable or amusing
#    pos score : 0.375
#    neg score : 0.0
#    obj score : 0.625
#
#    ('Center', False) -> center.n.01 : 0.0
#    definition : an area that is approximately central within some larger region
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('tough', False) -> street_fighter.n.02 : 0.0
#    definition : someone who learned to fight in the streets rather than being formally trained in the sport of boxing
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('loss', False) -> loss.n.01 : -0.25
#    definition : something that is lost
#    pos score : 0.0
#    neg score : 0.25
#    obj score : 0.75
#
#    ('See', False) -> see.n.01 : 0.0
#    definition : the seat within a bishop's diocese where his cathedral is located
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('tomorrow', False) -> tomorrow.n.01 : 0.0
#    definition : the day after today
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.125 / positive
#
#
# @rhymesayers a close 2nd is playing nothing but RSE on my drive to Soundset from California. Then nothing but RSE on the way back.
# a close nd is playing nothing but RSE on my drive to Soundset from California. Then nothing but RSE on the way back.
#
# [('a', 'DT'), ('close', 'JJ'), ('nd', 'NN'), ('is', 'VBZ'), ('playing', 'VBG'), ('nothing', 'NN'), ('but', 'CC'), ('RSE', 'NNP'), ('on', 'IN'), ('my', 'PRP$'), ('drive', 'NN'), ('to', 'TO'), ('Soundset', 'VB'), ('from', 'IN'), ('California.', 'NNP'), ('Then', 'RB'), ('nothing', 'NN'), ('but', 'CC'), ('RSE', 'NNP'), ('on', 'IN'), ('the', 'DT'), ('way', 'NN'), ('back.', 'NN')]
#
#    ('close', False) -> stopping_point.n.01 : 0.0
#    definition : the temporal end; the concluding time
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('nd', False) -> neodymium.n.01 : 0.0
#    definition : a yellow trivalent metallic element of the rare earth group; occurs in monazite and bastnasite in association with cerium and lanthanum and praseodymium
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('is', False) -> be.v.01 : 0.125
#    definition : have the quality of being; (copula, used with an adjective or a predicate noun)
#    pos score : 0.25
#    neg score : 0.125
#    obj score : 0.625
#
#    ('playing', False) -> playing.n.01 : 0.0
#    definition : the act of playing a musical instrument
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('nothing', False) -> nothing.n.01 : 0.0
#    definition : a quantity of no importance
#    pos score : 0.25
#    neg score : 0.25
#    obj score : 0.5
#
#    ('drive', False) -> drive.n.01 : 0.0
#    definition : the act of applying force to propel something
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('nothing', False) -> nothing.n.01 : 0.0
#    definition : a quantity of no importance
#    pos score : 0.25
#    neg score : 0.25
#    obj score : 0.5
#
#    ('way', False) -> manner.n.01 : 0.0
#    definition : how something is done or how it happens
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.125 / negative
#
#
# Dr Joe will kick off his Australian Tour with a lecture at The Conscious Club in Sydney, Australia, Thursday, May 17!  http://t.co/uaqUTMgO
# Dr Joe will kick off his Australian Tour with a lecture at The Conscious Club in Sydney, Australia, Thursday, May !
#
# [('Dr', 'NNP'), ('Joe', 'NNP'), ('will', 'MD'), ('kick', 'VB'), ('off', 'RP'), ('his', 'PRP$'), ('Australian', 'JJ'), ('Tour', 'NNP'), ('with', 'IN'), ('a', 'DT'), ('lecture', 'NN'), ('at', 'IN'), ('The', 'DT'), ('Conscious', 'NNP'), ('Club', 'NNP'), ('in', 'IN'), ('Sydney,', 'NNP'), ('Australia,', 'NNP'), ('Thursday,', 'NNP'), ('May', 'NNP'), ('!', '.')]
#
#    ('kick', False) -> kick.n.01 : 0.0
#    definition : the act of delivering a blow with the foot
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Australian', False) -> australian.n.01 : 0.0
#    definition : a native or inhabitant of Australia
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Tour', False) -> tour.n.01 : 0.0
#    definition : a journey or route all the way around a particular place or area
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('lecture', False) -> lecture.n.01 : 0.0
#    definition : a speech that is open to the public
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Conscious', False) -> conscious.s.01 : -0.125
#    definition : intentionally conceived
#    pos score : 0.125
#    neg score : 0.25
#    obj score : 0.625
#
#    ('Club', False) -> baseball_club.n.01 : 0.0
#    definition : a team of professional baseball players who play and travel together
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('May', False) -> may.n.01 : 0.0
#    definition : the month following April and preceding June
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = -0.125 / neutral
#
#
# Have a lovely Sunday and keep it MYSA
# Have a lovely Sunday and keep it MYSA
#
# [('Have', 'VBP'), ('a', 'DT'), ('lovely', 'JJ'), ('Sunday', 'NNP'), ('and', 'CC'), ('keep', 'VB'), ('it', 'PRP'), ('MYSA', 'NNP')]
#
#    ('Have', False) -> rich_person.n.01 : 0.0
#    definition : a person who possesses great material wealth
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('lovely', False) -> cover_girl.n.01 : 0.25
#    definition : a very pretty girl who works as a photographer's model
#    pos score : 0.25
#    neg score : 0.0
#    obj score : 0.75
#
#    ('Sunday', False) -> sunday.n.01 : 0.0
#    definition : first day of the week; observed as a day of rest and worship by most Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('keep', False) -> support.n.06 : 0.0
#    definition : the financial means whereby one lives
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.25 / positive

# %% [markdown]
# ### (2) Using PYWSD's max-similarity disambiguation function
#
# Semantic distance in WordNet: An experimental, application-oriented evaluation of five measures, Alexander Budanitsky and Graeme Hirst
#
#
# [ftp://learning.cs.utoronto.ca/public_html/public_html/pub/gh/Budanitsky+Hirst-2001.pdf](ftp://learning.cs.utoronto.ca/public_html/public_html/pub/gh/Budanitsky+Hirst-2001.pdf)

# %%
for i in tqdm(range(20)):
    cleaned_tweet = p.clean(tweets[i])
    replaced_tweet = replace_word(cleaned_tweet)
    da_token_pair_list = disambiguate(replaced_tweet, max_similarity, similarity_option='res')
    
    da_token_list = []
    for pair in da_token_pair_list:
        da_token_list.append(pair[0])
    
    tokens, token_pair_list = negate(da_token_list)
    
    print("####### Tweet " + str(i) + " #######" )
    print("")
    print(tweets[i])
    print(" -> " + replaced_tweet)
    print("")
    print(da_token_list)
    print("") 
    print(da_token_pair_list)
    print("") 
    print(token_pair_list)
    print("") 

    
    assert(len(da_token_pair_list) == len(token_pair_list))
    
    score = 0
    for j in range(len(da_token_pair_list)):
        curr_neg = False
        if token_pair_list[j][1]:
            print("negated : " + token_pair_list[j][0])
            curr_neg = True
        
        curr_ss = da_token_pair_list[j][1]
        curr_score = 0
        if curr_ss:

            ## NOT a good sentiment scoring function
            pos_score = swn.senti_synset(curr_ss.name()).pos_score() 
            neg_score = swn.senti_synset(curr_ss.name()).neg_score()
            curr_score += (pos_score - neg_score)
            if curr_neg:
                curr_score *= -1
            print("   " + str(token_pair_list[j]) + " -> " + curr_ss.name() + " : " + str(curr_score))
            print("   definition : " + wn.synset(curr_ss.name()).definition())
            print("   pos score : " + str(pos_score))
            print("   neg score : " + str(neg_score))
            print("   obj score : " + str(swn.senti_synset(curr_ss.name()).obj_score()))
            print("")
            score += curr_score            
            
        else:
            continue
    print("  TOTAL score = " + str(score) + " / " + labels[i])
    print("")
# Out:
#   5%|▌         | 1/20 [00:07<02:30,  7.94s/it]
# ####### Tweet 0 #######
#
# dec 21st 2012 will be know not as the end of the world but the Baby Boom! #2012shit
#  -> dec st will be know not as the end of the world but the Baby Boom!
#
# ['dec', 'st', 'will', 'be', 'know', 'not', 'as', 'the', 'end', 'of', 'the', 'world', 'but', 'the', 'Baby', 'Boom', '!']
#
# [('dec', Synset('december.n.01')), ('st', None), ('will', None), ('be', None), ('know', None), ('not', None), ('as', None), ('the', None), ('end', Synset('goal.n.01')), ('of', None), ('the', None), ('world', Synset('populace.n.01')), ('but', None), ('the', None), ('Baby', Synset('child.n.03')), ('Boom', Synset('boom.n.01')), ('!', None)]
#
# [('dec', False), ('st', False), ('will', False), ('be', False), ('know', False), ('not', False), ('as', True), ('the', True), ('end', True), ('of', True), ('the', True), ('world', True), ('but', True), ('the', True), ('Baby', True), ('Boom', True), ('!', False)]
#
#    ('dec', False) -> december.n.01 : 0.0
#    definition : the last (12th) month of the year
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : as
# negated : the
# negated : end
#    ('end', True) -> goal.n.01 : -0.0
#    definition : the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : of
# negated : the
# negated : world
#    ('world', True) -> populace.n.01 : -0.0
#    definition : people in general considered as a whole
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : but
# negated : the
# negated : Baby
#    ('Baby', True) -> child.n.03 : -0.0
#    definition : an immature childish person
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : Boom
#    ('Boom', True) -> boom.n.01 : -0.0
#    definition : a deep prolonged loud noise
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / neutral
#  10%|█         | 2/20 [00:22<03:26, 11.47s/it]
# ####### Tweet 1 #######
#
# @MacMiller hate my life, because i can't see you at the roskilde festival on saturday, promise me to come back again, SOON.
#  -> hate my life, because i can not see you at the roskilde festival on saturday, promise me to come back again, SOON.
#
# ['hate', 'my', 'life', ',', 'because', 'i', 'can', 'not', 'see', 'you', 'at', 'the', 'roskilde', 'festival', 'on', 'saturday', ',', 'promise', 'me', 'to', 'come', 'back', 'again', ',', 'SOON', '.']
#
# [('hate', Synset('hate.v.01')), ('my', None), ('life', Synset('life.n.07')), (',', None), ('because', None), ('i', None), ('can', None), ('not', None), ('see', Synset('see.v.05')), ('you', None), ('at', None), ('the', None), ('roskilde', None), ('festival', Synset('festival.n.02')), ('on', None), ('saturday', Synset('saturday.n.01')), (',', None), ('promise', Synset('promise.v.01')), ('me', None), ('to', None), ('come', Synset('do.v.04')), ('back', None), ('again', None), (',', None), ('SOON', None), ('.', None)]
#
# [('hate', False), ('my', False), ('life', False), (',', False), ('because', False), ('i', False), ('can', False), ('not', False), ('see', True), ('you', True), ('at', True), ('the', True), ('roskilde', True), ('festival', True), ('on', True), ('saturday', True), (',', False), ('promise', False), ('me', False), ('to', False), ('come', False), ('back', False), ('again', False), (',', False), ('SOON', False), ('.', False)]
#
#    ('hate', False) -> hate.v.01 : -0.75
#    definition : dislike intensely; feel antipathy or aversion towards
#    pos score : 0.0
#    neg score : 0.75
#    obj score : 0.25
#
#    ('life', False) -> life.n.07 : 0.0
#    definition : the period from the present until death
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : see
#    ('see', True) -> see.v.05 : -0.125
#    definition : deem to be
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
# negated : you
# negated : at
# negated : the
# negated : roskilde
# negated : festival
#    ('festival', True) -> festival.n.02 : -0.0
#    definition : an organized series of acts and performances (usually in one place)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : on
# negated : saturday
#    ('saturday', True) -> saturday.n.01 : -0.0
#    definition : the seventh and last day of the week; observed as the Sabbath by Jews and some Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('promise', False) -> promise.v.01 : 0.0
#    definition : make a promise or commitment
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('come', False) -> do.v.04 : 0.0
#    definition : proceed or get along
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = -0.875 / negative
#  15%|█▌        | 3/20 [00:36<03:27, 12.21s/it]
# ####### Tweet 2 #######
#
# Checked out Our Lady Peace at Bluesfest tonight and spending the day at the beach for HOPE volleyball tomorrow. Gotta love summer weekends!
#  -> Checked out Our Lady Peace at Bluesfest tonight and spending the day at the beach for HOPE volleyball tomorrow. Gotta love summer weekends!
#
# ['Checked', 'out', 'Our', 'Lady', 'Peace', 'at', 'Bluesfest', 'tonight', 'and', 'spending', 'the', 'day', 'at', 'the', 'beach', 'for', 'HOPE', 'volleyball', 'tomorrow', '.', 'Got', 'ta', 'love', 'summer', 'weekends', '!']
#
# [('Checked', Synset('match.v.01')), ('out', None), ('Our', None), ('Lady', None), ('Peace', Synset('peace.n.01')), ('at', None), ('Bluesfest', None), ('tonight', Synset('tonight.n.01')), ('and', None), ('spending', Synset('spend.v.01')), ('the', None), ('day', Synset('day.n.04')), ('at', None), ('the', None), ('beach', Synset('beach.n.01')), ('for', None), ('HOPE', Synset('promise.n.02')), ('volleyball', Synset('volleyball.n.01')), ('tomorrow', Synset('tomorrow.n.01')), ('.', None), ('Got', None), ('ta', None), ('love', Synset('sleep_together.v.01')), ('summer', Synset('summer.n.01')), ('weekends', Synset('weekend.n.01')), ('!', None)]
#
# [('Checked', False), ('out', False), ('Our', False), ('Lady', False), ('Peace', False), ('at', False), ('Bluesfest', False), ('tonight', False), ('and', False), ('spending', False), ('the', False), ('day', False), ('at', False), ('the', False), ('beach', False), ('for', False), ('HOPE', False), ('volleyball', False), ('tomorrow', False), ('.', False), ('Got', False), ('ta', False), ('love', False), ('summer', False), ('weekends', False), ('!', False)]
#
#    ('Checked', False) -> match.v.01 : 0.375
#    definition : be compatible, similar or consistent; coincide in their characteristics
#    pos score : 0.375
#    neg score : 0.0
#    obj score : 0.625
#
#    ('Peace', False) -> peace.n.01 : 0.125
#    definition : the state prevailing during the absence of war
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('tonight', False) -> tonight.n.01 : 0.0
#    definition : the present or immediately coming night
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('spending', False) -> spend.v.01 : 0.125
#    definition : pass time in a specific way
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('day', False) -> day.n.04 : 0.0
#    definition : the time after sunrise and before sunset while it is light outside
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('beach', False) -> beach.n.01 : 0.0
#    definition : an area of sand sloping down to the water of a sea or lake
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('HOPE', False) -> promise.n.02 : -0.125
#    definition : grounds for feeling hopeful about the future
#    pos score : 0.125
#    neg score : 0.25
#    obj score : 0.625
#
#    ('volleyball', False) -> volleyball.n.01 : 0.0
#    definition : a game in which two teams hit an inflated ball over a high net using their hands
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('tomorrow', False) -> tomorrow.n.01 : 0.0
#    definition : the day after today
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('love', False) -> sleep_together.v.01 : 0.25
#    definition : have sexual intercourse with
#    pos score : 0.375
#    neg score : 0.125
#    obj score : 0.5
#
#    ('summer', False) -> summer.n.01 : 0.0
#    definition : the warmest season of the year; in the northern hemisphere it extends from the summer solstice to the autumnal equinox
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('weekends', False) -> weekend.n.01 : 0.0
#    definition : a time period usually extending from Friday night through Sunday; more loosely defined as any period of successive days including one and only one Sunday
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.75 / positive
#  20%|██        | 4/20 [00:49<03:18, 12.41s/it]
# ####### Tweet 3 #######
#
# Hello from the Foundation Trekkers! We're up in chilly Haltwhistle getting ready to trek Hadrian's wall tomorrow :-) http://t.co/MmRnhLAL
#  -> Hello from the Foundation Trekkers! We're up in chilly Haltwhistle getting ready to trek Hadrian's wall tomorrow
#
# ['Hello', 'from', 'the', 'Foundation', 'Trekkers', '!', 'We', "'re", 'up', 'in', 'chilly', 'Haltwhistle', 'getting', 'ready', 'to', 'trek', 'Hadrian', "'s", 'wall', 'tomorrow']
#
# [('Hello', Synset('hello.n.01')), ('from', None), ('the', None), ('Foundation', Synset('foundation.n.01')), ('Trekkers', Synset('trekker.n.01')), ('!', None), ('We', None), ("'re", None), ('up', None), ('in', None), ('chilly', None), ('Haltwhistle', None), ('getting', Synset('get.v.01')), ('ready', None), ('to', None), ('trek', Synset('trek.v.01')), ('Hadrian', Synset('hadrian.n.01')), ("'s", None), ('wall', Synset('rampart.n.01')), ('tomorrow', Synset('tomorrow.n.01'))]
#
# [('Hello', False), ('from', False), ('the', False), ('Foundation', False), ('Trekkers', False), ('!', False), ('We', False), ("'re", False), ('up', False), ('in', False), ('chilly', False), ('Haltwhistle', False), ('getting', False), ('ready', False), ('to', False), ('trek', False), ('Hadrian', False), ("'s", False), ('wall', False), ('tomorrow', False)]
#
#    ('Hello', False) -> hello.n.01 : 0.0
#    definition : an expression of greeting
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Foundation', False) -> foundation.n.01 : 0.0
#    definition : the basis on which something is grounded
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Trekkers', False) -> trekker.n.01 : 0.0
#    definition : a traveler who makes a long arduous journey (as hiking through mountainous country)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('getting', False) -> get.v.01 : 0.125
#    definition : come into the possession of something concrete or abstract
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('trek', False) -> trek.v.01 : 0.0
#    definition : journey on foot, especially in the mountains
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Hadrian', False) -> hadrian.n.01 : 0.0
#    definition : Roman Emperor who was the adoptive son of Trajan; travelled throughout his empire to strengthen its frontiers and encourage learning and architecture; on a visit to Britain in 122 he ordered the construction of Hadrian's Wall (76-138)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('wall', False) -> rampart.n.01 : 0.0
#    definition : an embankment built around a space for defensive purposes
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('tomorrow', False) -> tomorrow.n.01 : 0.0
#    definition : the day after today
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.125 / positive
#  25%|██▌       | 5/20 [01:03<03:11, 12.75s/it]
# ####### Tweet 4 #######
#
# Tomorrow we will be proud to play at the Remembrance Service at South Hetton church
#  -> Tomorrow we will be proud to play at the Remembrance Service at South Hetton church
#
# ['Tomorrow', 'we', 'will', 'be', 'proud', 'to', 'play', 'at', 'the', 'Remembrance', 'Service', 'at', 'South', 'Hetton', 'church']
#
# [('Tomorrow', Synset('tomorrow.n.01')), ('we', None), ('will', None), ('be', None), ('proud', None), ('to', None), ('play', Synset('play.v.01')), ('at', None), ('the', None), ('Remembrance', Synset('memorial.n.01')), ('Service', Synset('serve.n.01')), ('at', None), ('South', Synset('south.n.03')), ('Hetton', None), ('church', Synset('church.n.02'))]
#
# [('Tomorrow', False), ('we', False), ('will', False), ('be', False), ('proud', False), ('to', False), ('play', False), ('at', False), ('the', False), ('Remembrance', False), ('Service', False), ('at', False), ('South', False), ('Hetton', False), ('church', False)]
#
#    ('Tomorrow', False) -> tomorrow.n.01 : 0.0
#    definition : the day after today
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('play', False) -> play.v.01 : 0.0
#    definition : participate in games or sport
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Remembrance', False) -> memorial.n.01 : 0.375
#    definition : a recognition of meritorious service
#    pos score : 0.375
#    neg score : 0.0
#    obj score : 0.625
#
#    ('Service', False) -> serve.n.01 : 0.0
#    definition : (sports) a stroke that puts the ball in play
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('South', False) -> south.n.03 : 0.0
#    definition : the cardinal compass point that is at 180 degrees
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('church', False) -> church.n.02 : 0.0
#    definition : a place for public (especially Christian) worship
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.375 / positive
#  30%|███       | 6/20 [01:18<03:03, 13.10s/it]
# ####### Tweet 5 #######
#
# Impulsively bought Resident Evil: Operation Raccoon City. Probably won't play it till tomorrow though. Have so much editing to do with 06.
#  -> Impulsively bought Resident Evil: Operation Raccoon City. Probably will not play it till tomorrow though. Have so much editing to do with .
#
# ['Impulsively', 'bought', 'Resident', 'Evil', ':', 'Operation', 'Raccoon', 'City', '.', 'Probably', 'will', 'not', 'play', 'it', 'till', 'tomorrow', 'though', '.', 'Have', 'so', 'much', 'editing', 'to', 'do', 'with', '.']
#
# [('Impulsively', None), ('bought', Synset('buy.v.01')), ('Resident', Synset('resident.n.01')), ('Evil', Synset('evil.n.03')), (':', None), ('Operation', Synset('process.n.02')), ('Raccoon', Synset('raccoon.n.02')), ('City', Synset('city.n.01')), ('.', None), ('Probably', None), ('will', None), ('not', None), ('play', Synset('play.v.01')), ('it', None), ('till', None), ('tomorrow', Synset('tomorrow.n.01')), ('though', None), ('.', None), ('Have', None), ('so', None), ('much', None), ('editing', Synset('editing.n.01')), ('to', None), ('do', None), ('with', None), ('.', None)]
#
# [('Impulsively', False), ('bought', False), ('Resident', False), ('Evil', False), (':', False), ('Operation', False), ('Raccoon', False), ('City', False), ('.', False), ('Probably', False), ('will', False), ('not', False), ('play', True), ('it', True), ('till', True), ('tomorrow', True), ('though', True), ('.', False), ('Have', False), ('so', False), ('much', False), ('editing', False), ('to', False), ('do', False), ('with', False), ('.', False)]
#
#    ('bought', False) -> buy.v.01 : 0.0
#    definition : obtain by purchase; acquire by means of a financial transaction
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Resident', False) -> resident.n.01 : 0.0
#    definition : someone who lives at a particular place for a prolonged period or who was born there
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Evil', False) -> evil.n.03 : -0.125
#    definition : the quality of being morally wrong in principle or practice
#    pos score : 0.375
#    neg score : 0.5
#    obj score : 0.125
#
#    ('Operation', False) -> process.n.02 : 0.0
#    definition : (psychology) the performance of some composite cognitive activity; an operation that affects mental contents
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Raccoon', False) -> raccoon.n.02 : 0.0
#    definition : an omnivorous nocturnal mammal native to North America and Central America
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('City', False) -> city.n.01 : 0.0
#    definition : a large and densely populated urban area; may include several independent administrative districts
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : play
#    ('play', True) -> play.v.01 : -0.0
#    definition : participate in games or sport
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : it
# negated : till
# negated : tomorrow
#    ('tomorrow', True) -> tomorrow.n.01 : -0.0
#    definition : the day after today
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : though
#    ('editing', False) -> editing.n.01 : 0.0
#    definition : putting something (as a literary work or a legislative bill) into acceptable form
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = -0.125 / negative
#  35%|███▌      | 7/20 [01:26<02:41, 12.39s/it]
# ####### Tweet 6 #######
#
# Just arriving in madrid from Moscow Tomorrow going to HVar, Croatia
#  -> Just arriving in madrid from Moscow Tomorrow going to HVar, Croatia
#
# ['Just', 'arriving', 'in', 'madrid', 'from', 'Moscow', 'Tomorrow', 'going', 'to', 'HVar', ',', 'Croatia']
#
# [('Just', None), ('arriving', Synset('arrive.v.01')), ('in', None), ('madrid', Synset('madrid.n.01')), ('from', None), ('Moscow', Synset('moscow.n.01')), ('Tomorrow', Synset('tomorrow.n.01')), ('going', Synset('travel.v.01')), ('to', None), ('HVar', None), (',', None), ('Croatia', Synset('croatia.n.01'))]
#
# [('Just', False), ('arriving', False), ('in', False), ('madrid', False), ('from', False), ('Moscow', False), ('Tomorrow', False), ('going', False), ('to', False), ('HVar', False), (',', False), ('Croatia', False)]
#
#    ('arriving', False) -> arrive.v.01 : 0.0
#    definition : reach a destination; arrive by movement or progress
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('madrid', False) -> madrid.n.01 : 0.0
#    definition : the capital and largest city situated centrally in Spain; home of an outstanding art museum
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Moscow', False) -> moscow.n.01 : 0.0
#    definition : a city of central European Russia; formerly capital of both the Soviet Union and Soviet Russia; since 1991 the capital of the Russian Federation
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Tomorrow', False) -> tomorrow.n.01 : 0.0
#    definition : the day after today
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('going', False) -> travel.v.01 : 0.0
#    definition : change location; move, travel, or proceed, also metaphorically
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Croatia', False) -> croatia.n.01 : 0.0
#    definition : a republic in the western Balkans in south-central Europe in the eastern Adriatic coastal area; formerly part of the Habsburg monarchy and Yugoslavia; became independent in 1991
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / neutral
#  40%|████      | 8/20 [01:35<02:23, 11.95s/it]
# ####### Tweet 7 #######
#
# Just packing for a weekend in Liverpool and the small matter of a marathon on Sunday. First up though...Blackpool Illuminations!
#  -> Just packing for a weekend in Liverpool and the small matter of a marathon on Sunday. First up though...Blackpool Illuminations!
#
# ['Just', 'packing', 'for', 'a', 'weekend', 'in', 'Liverpool', 'and', 'the', 'small', 'matter', 'of', 'a', 'marathon', 'on', 'Sunday', '.', 'First', 'up', 'though', '...', 'Blackpool', 'Illuminations', '!']
#
# [('Just', None), ('packing', Synset('carry.v.02')), ('for', None), ('a', None), ('weekend', Synset('weekend.n.01')), ('in', None), ('Liverpool', Synset('liverpool.n.01')), ('and', None), ('the', None), ('small', None), ('matter', Synset('matter.n.03')), ('of', None), ('a', None), ('marathon', Synset('marathon.n.03')), ('on', None), ('Sunday', Synset('sunday.n.01')), ('.', None), ('First', Synset('first.n.01')), ('up', None), ('though', None), ('...', None), ('Blackpool', Synset('blackpool.n.01')), ('Illuminations', Synset('illumination.n.02')), ('!', None)]
#
# [('Just', False), ('packing', False), ('for', False), ('a', False), ('weekend', False), ('in', False), ('Liverpool', False), ('and', False), ('the', False), ('small', False), ('matter', False), ('of', False), ('a', False), ('marathon', False), ('on', False), ('Sunday', False), ('.', False), ('First', False), ('up', False), ('though', False), ('...', False), ('Blackpool', False), ('Illuminations', False), ('!', False)]
#
#    ('packing', False) -> carry.v.02 : 0.0
#    definition : have with oneself; have on one's person
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('weekend', False) -> weekend.n.01 : 0.0
#    definition : a time period usually extending from Friday night through Sunday; more loosely defined as any period of successive days including one and only one Sunday
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Liverpool', False) -> liverpool.n.01 : 0.0
#    definition : a large city in northwestern England; its port is the country's major outlet for industrial exports
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('matter', False) -> matter.n.03 : 0.0
#    definition : that which has mass and occupies space
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('marathon', False) -> marathon.n.03 : 0.0
#    definition : a battle in 490 BC in which the Athenians and their allies defeated the Persians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Sunday', False) -> sunday.n.01 : 0.0
#    definition : first day of the week; observed as a day of rest and worship by most Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('First', False) -> first.n.01 : 0.0
#    definition : the first or highest in an ordering or series
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Blackpool', False) -> blackpool.n.01 : 0.0
#    definition : a resort town in Lancashire in northwestern England on the Irish Sea; famous for its tower
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Illuminations', False) -> illumination.n.02 : -0.125
#    definition : the degree of visibility of your environment
#    pos score : 0.0
#    neg score : 0.125
#    obj score : 0.875
#
#   TOTAL score = -0.125 / neutral
#  45%|████▌     | 9/20 [01:42<02:04, 11.36s/it]
# ####### Tweet 8 #######
#
# Your plans of attending the Great Yorkshire Show may have been washed out because of the weather, so how about... http://t.co/fEsAtbk8
#  -> Your plans of attending the Great Yorkshire Show may have been washed out because of the weather, so how about...
#
# ['Your', 'plans', 'of', 'attending', 'the', 'Great', 'Yorkshire', 'Show', 'may', 'have', 'been', 'washed', 'out', 'because', 'of', 'the', 'weather', ',', 'so', 'how', 'about', '...']
#
# [('Your', None), ('plans', Synset('plan.n.01')), ('of', None), ('attending', Synset('attend.v.02')), ('the', None), ('Great', Synset('great.n.01')), ('Yorkshire', Synset('yorkshire.n.01')), ('Show', Synset('show.n.03')), ('may', Synset('whitethorn.n.01')), ('have', None), ('been', None), ('washed', Synset('wash.v.02')), ('out', None), ('because', None), ('of', None), ('the', None), ('weather', Synset('weather.n.01')), (',', None), ('so', None), ('how', None), ('about', None), ('...', None)]
#
# [('Your', False), ('plans', False), ('of', False), ('attending', False), ('the', False), ('Great', False), ('Yorkshire', False), ('Show', False), ('may', False), ('have', False), ('been', False), ('washed', False), ('out', False), ('because', False), ('of', False), ('the', False), ('weather', False), (',', False), ('so', False), ('how', False), ('about', False), ('...', False)]
#
#    ('plans', False) -> plan.n.01 : 0.0
#    definition : a series of steps to be carried out or goals to be accomplished
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('attending', False) -> attend.v.02 : 0.0
#    definition : take charge of or deal with
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Great', False) -> great.n.01 : 0.0
#    definition : a person who has achieved distinction and honor in some field
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Yorkshire', False) -> yorkshire.n.01 : 0.0
#    definition : a former large county in northern England; in 1974 it was divided into three smaller counties
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Show', False) -> show.n.03 : 0.0
#    definition : a social event involving a public performance or entertainment
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('may', False) -> whitethorn.n.01 : 0.0
#    definition : thorny Eurasian shrub of small tree having dense clusters of white to scarlet flowers followed by deep red berries; established as an escape in eastern North America
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('washed', False) -> wash.v.02 : 0.0
#    definition : cleanse (one's body) with soap and water
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('weather', False) -> weather.n.01 : 0.0
#    definition : the atmospheric conditions that comprise the state of the atmosphere in terms of temperature and wind and clouds and precipitation
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / negative
#  50%|█████     | 10/20 [02:12<02:12, 13.29s/it]
# ####### Tweet 9 #######
#
# By the end of today I will have worked 14hrs, done my workout and attended part of Hot Jam. Hitting the ground running this Monday.
#  -> By the end of today I will have worked hrs, done my workout and attended part of Hot Jam. Hitting the ground running this Monday.
#
# ['By', 'the', 'end', 'of', 'today', 'I', 'will', 'have', 'worked', 'hrs', ',', 'done', 'my', 'workout', 'and', 'attended', 'part', 'of', 'Hot', 'Jam', '.', 'Hitting', 'the', 'ground', 'running', 'this', 'Monday', '.']
#
# [('By', None), ('the', None), ('end', Synset('goal.n.01')), ('of', None), ('today', Synset('today.n.01')), ('I', None), ('will', None), ('have', None), ('worked', Synset('work.v.02')), ('hrs', Synset('hour.n.01')), (',', None), ('done', None), ('my', None), ('workout', Synset('exercise.n.01')), ('and', None), ('attended', Synset('attend.v.02')), ('part', Synset('part.n.01')), ('of', None), ('Hot', None), ('Jam', Synset('crush.n.02')), ('.', None), ('Hitting', Synset('score.v.01')), ('the', None), ('ground', Synset('land.n.04')), ('running', Synset('run.v.03')), ('this', None), ('Monday', Synset('monday.n.01')), ('.', None)]
#
# [('By', False), ('the', False), ('end', False), ('of', False), ('today', False), ('I', False), ('will', False), ('have', False), ('worked', False), ('hrs', False), (',', False), ('done', False), ('my', False), ('workout', False), ('and', False), ('attended', False), ('part', False), ('of', False), ('Hot', False), ('Jam', False), ('.', False), ('Hitting', False), ('the', False), ('ground', False), ('running', False), ('this', False), ('Monday', False), ('.', False)]
#
#    ('end', False) -> goal.n.01 : 0.0
#    definition : the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('today', False) -> today.n.01 : 0.125
#    definition : the present time or age
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('worked', False) -> work.v.02 : 0.0
#    definition : be employed
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('hrs', False) -> hour.n.01 : 0.0
#    definition : a period of time equal to 1/24th of a day
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('workout', False) -> exercise.n.01 : 0.0
#    definition : the activity of exerting your muscles in various ways to keep fit
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('attended', False) -> attend.v.02 : 0.0
#    definition : take charge of or deal with
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('part', False) -> part.n.01 : 0.0
#    definition : something determined in relation to something that includes it
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Jam', False) -> crush.n.02 : 0.0
#    definition : a dense crowd of people
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Hitting', False) -> score.v.01 : 0.0
#    definition : gain points in a game
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('ground', False) -> land.n.04 : 0.0
#    definition : the solid part of the earth's surface
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('running', False) -> run.v.03 : 0.0
#    definition : stretch out over a distance, space, time, or scope; run or extend between two points or beyond a certain point
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Monday', False) -> monday.n.01 : 0.0
#    definition : the second day of the week; the first working day
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.125 / neutral
#  55%|█████▌    | 11/20 [02:28<02:01, 13.47s/it]
# ####### Tweet 10 #######
#
# Check out this weeks the @SixersBBL Scoop column looking back on Sat Nights win over the Thunder! http://t.co/lRto77al #smashemsixers #BBL02
#  -> Check out this weeks the Scoop column looking back on Sat Nights win over the Thunder!
#
# ['Check', 'out', 'this', 'weeks', 'the', 'Scoop', 'column', 'looking', 'back', 'on', 'Sat', 'Nights', 'win', 'over', 'the', 'Thunder', '!']
#
# [('Check', Synset('match.v.01')), ('out', None), ('this', None), ('weeks', Synset('week.n.01')), ('the', None), ('Scoop', Synset('exclusive.n.01')), ('column', Synset('column.n.04')), ('looking', Synset('look.v.02')), ('back', None), ('on', None), ('Sat', Synset('saturday.n.01')), ('Nights', Synset('night.n.01')), ('win', Synset('winnings.n.01')), ('over', None), ('the', None), ('Thunder', Synset('boom.n.01')), ('!', None)]
#
# [('Check', False), ('out', False), ('this', False), ('weeks', False), ('the', False), ('Scoop', False), ('column', False), ('looking', False), ('back', False), ('on', False), ('Sat', False), ('Nights', False), ('win', False), ('over', False), ('the', False), ('Thunder', False), ('!', False)]
#
#    ('Check', False) -> match.v.01 : 0.375
#    definition : be compatible, similar or consistent; coincide in their characteristics
#    pos score : 0.375
#    neg score : 0.0
#    obj score : 0.625
#
#    ('weeks', False) -> week.n.01 : 0.0
#    definition : any period of seven consecutive days
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Scoop', False) -> exclusive.n.01 : 0.0
#    definition : a news report that is reported first by one news organization
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('column', False) -> column.n.04 : 0.125
#    definition : anything that approximates the shape of a column or tower
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('looking', False) -> look.v.02 : 0.0
#    definition : give a certain impression or have a certain outward aspect
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Sat', False) -> saturday.n.01 : 0.0
#    definition : the seventh and last day of the week; observed as the Sabbath by Jews and some Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Nights', False) -> night.n.01 : 0.0
#    definition : the time after sunset and before sunrise while it is dark outside
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('win', False) -> winnings.n.01 : 0.0
#    definition : something won (especially money)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Thunder', False) -> boom.n.01 : 0.0
#    definition : a deep prolonged loud noise
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.5 / neutral
#  60%|██████    | 12/20 [02:50<01:53, 14.20s/it]
# ####### Tweet 11 #######
#
# Three day weekend a head. Tonight Grand Bend forracing, Saturday Grand Bend with the inlaws more racing. Sunday first #Sting game for us.
#  -> Three day weekend a head. Tonight Grand Bend forracing, Saturday Grand Bend with the inlaws more racing. Sunday first game for us.
#
# ['Three', 'day', 'weekend', 'a', 'head', '.', 'Tonight', 'Grand', 'Bend', 'forracing', ',', 'Saturday', 'Grand', 'Bend', 'with', 'the', 'inlaws', 'more', 'racing', '.', 'Sunday', 'first', 'game', 'for', 'us', '.']
#
# [('Three', None), ('day', Synset('day.n.04')), ('weekend', Synset('weekend.n.01')), ('a', None), ('head', Synset('head.n.04')), ('.', None), ('Tonight', Synset('tonight.n.01')), ('Grand', Synset('thousand.n.01')), ('Bend', Synset('bend.n.01')), ('forracing', None), (',', None), ('Saturday', Synset('saturday.n.01')), ('Grand', Synset('thousand.n.01')), ('Bend', Synset('bend.n.01')), ('with', None), ('the', None), ('inlaws', None), ('more', None), ('racing', Synset('racing.n.01')), ('.', None), ('Sunday', Synset('sunday.n.01')), ('first', None), ('game', Synset('game.n.01')), ('for', None), ('us', None), ('.', None)]
#
# [('Three', False), ('day', False), ('weekend', False), ('a', False), ('head', False), ('.', False), ('Tonight', False), ('Grand', False), ('Bend', False), ('forracing', False), (',', False), ('Saturday', False), ('Grand', False), ('Bend', False), ('with', False), ('the', False), ('inlaws', False), ('more', False), ('racing', False), ('.', False), ('Sunday', False), ('first', False), ('game', False), ('for', False), ('us', False), ('.', False)]
#
#    ('day', False) -> day.n.04 : 0.0
#    definition : the time after sunrise and before sunset while it is light outside
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('weekend', False) -> weekend.n.01 : 0.0
#    definition : a time period usually extending from Friday night through Sunday; more loosely defined as any period of successive days including one and only one Sunday
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('head', False) -> head.n.04 : 0.0
#    definition : a person who is in charge
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Tonight', False) -> tonight.n.01 : 0.0
#    definition : the present or immediately coming night
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Grand', False) -> thousand.n.01 : 0.0
#    definition : the cardinal number that is the product of 10 and 100
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Bend', False) -> bend.n.01 : 0.0
#    definition : a circular segment of a curve
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Saturday', False) -> saturday.n.01 : 0.0
#    definition : the seventh and last day of the week; observed as the Sabbath by Jews and some Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Grand', False) -> thousand.n.01 : 0.0
#    definition : the cardinal number that is the product of 10 and 100
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Bend', False) -> bend.n.01 : 0.0
#    definition : a circular segment of a curve
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('racing', False) -> racing.n.01 : 0.0
#    definition : the sport of engaging in contests of speed
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Sunday', False) -> sunday.n.01 : 0.0
#    definition : first day of the week; observed as a day of rest and worship by most Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('game', False) -> game.n.01 : 0.0
#    definition : a contest with rules to determine a winner
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / positive
#  65%|██████▌   | 13/20 [03:19<01:47, 15.32s/it]
# ####### Tweet 12 #######
#
# Have you been inspired by Ironman Wales? Why not give triathlon a go by taking part in the Fishguard Go Tri on Sunday. http://t.co/lDfNW2fG
#  -> Have you been inspired by Ironman Wales? Why not give triathlon a go by taking part in the Fishguard Go Tri on Sunday.
#
# ['Have', 'you', 'been', 'inspired', 'by', 'Ironman', 'Wales', '?', 'Why', 'not', 'give', 'triathlon', 'a', 'go', 'by', 'taking', 'part', 'in', 'the', 'Fishguard', 'Go', 'Tri', 'on', 'Sunday', '.']
#
# [('Have', None), ('you', None), ('been', None), ('inspired', Synset('inspire.v.01')), ('by', None), ('Ironman', Synset('iron_man.n.01')), ('Wales', Synset('wale.n.01')), ('?', None), ('Why', None), ('not', None), ('give', Synset('impart.v.01')), ('triathlon', None), ('a', None), ('go', Synset('crack.n.09')), ('by', None), ('taking', Synset('take.v.02')), ('part', Synset('part.n.01')), ('in', None), ('the', None), ('Fishguard', None), ('Go', Synset('crack.n.09')), ('Tri', None), ('on', None), ('Sunday', Synset('sunday.n.01')), ('.', None)]
#
# [('Have', False), ('you', False), ('been', False), ('inspired', False), ('by', False), ('Ironman', False), ('Wales', False), ('?', False), ('Why', False), ('not', False), ('give', True), ('triathlon', True), ('a', True), ('go', True), ('by', True), ('taking', True), ('part', True), ('in', True), ('the', True), ('Fishguard', True), ('Go', True), ('Tri', True), ('on', True), ('Sunday', True), ('.', False)]
#
#    ('inspired', False) -> inspire.v.01 : 0.125
#    definition : heighten or intensify
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('Ironman', False) -> iron_man.n.01 : 0.25
#    definition : a strong man of exceptional physical endurance
#    pos score : 0.25
#    neg score : 0.0
#    obj score : 0.75
#
#    ('Wales', False) -> wale.n.01 : 0.0
#    definition : a raised mark on the skin (as produced by the blow of a whip); characteristic of many allergic reactions
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : give
#    ('give', True) -> impart.v.01 : -0.0
#    definition : transmit (knowledge or skills)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : triathlon
# negated : a
# negated : go
#    ('go', True) -> crack.n.09 : -0.0
#    definition : a usually brief attempt
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : by
# negated : taking
#    ('taking', True) -> take.v.02 : -0.125
#    definition : require (time or space)
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
# negated : part
#    ('part', True) -> part.n.01 : -0.0
#    definition : something determined in relation to something that includes it
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : in
# negated : the
# negated : Fishguard
# negated : Go
#    ('Go', True) -> crack.n.09 : -0.0
#    definition : a usually brief attempt
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
# negated : Tri
# negated : on
# negated : Sunday
#    ('Sunday', True) -> sunday.n.01 : -0.0
#    definition : first day of the week; observed as a day of rest and worship by most Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.25 / positive
#  70%|███████   | 14/20 [03:30<01:30, 15.01s/it]
# ####### Tweet 13 #######
#
# I've found lyrics of Kiryu - Kaika!!! YES!!! but I've sat down to listen a song and write it already...))
#  -> I've found lyrics of Kiryu - Kaika!!! YES!!! but I've sat down to listen a song and write it already...))
#
# ['I', "'ve", 'found', 'lyrics', 'of', 'Kiryu', '-', 'Kaika', '!', '!', '!', 'YES', '!', '!', '!', 'but', 'I', "'ve", 'sat', 'down', 'to', 'listen', 'a', 'song', 'and', 'write', 'it', 'already', '...', ')', ')']
#
# [('I', None), ("'ve", None), ('found', Synset('determine.v.01')), ('lyrics', Synset('lyric.n.01')), ('of', None), ('Kiryu', None), ('-', None), ('Kaika', None), ('!', None), ('!', None), ('!', None), ('YES', Synset('yes.n.01')), ('!', None), ('!', None), ('!', None), ('but', None), ('I', None), ("'ve", None), ('sat', Synset('sit.v.01')), ('down', None), ('to', None), ('listen', Synset('listen.v.02')), ('a', None), ('song', Synset('song.n.01')), ('and', None), ('write', Synset('write.v.02')), ('it', None), ('already', None), ('...', None), (')', None), (')', None)]
#
# [('I', False), ("'ve", False), ('found', False), ('lyrics', False), ('of', False), ('Kiryu', False), ('-', False), ('Kaika', False), ('!', False), ('!', False), ('!', False), ('YES', False), ('!', False), ('!', False), ('!', False), ('but', False), ('I', False), ("'ve", False), ('sat', False), ('down', False), ('to', False), ('listen', False), ('a', False), ('song', False), ('and', False), ('write', False), ('it', False), ('already', False), ('...', False), (')', False), (')', False)]
#
#    ('found', False) -> determine.v.01 : 0.0
#    definition : establish after a calculation, investigation, experiment, survey, or study
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('lyrics', False) -> lyric.n.01 : 0.0
#    definition : the text of a popular song or musical-comedy number
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('YES', False) -> yes.n.01 : 0.25
#    definition : an affirmative
#    pos score : 0.25
#    neg score : 0.0
#    obj score : 0.75
#
#    ('sat', False) -> sit.v.01 : 0.0
#    definition : be seated
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('listen', False) -> listen.v.02 : 0.0
#    definition : listen and pay attention
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('song', False) -> song.n.01 : 0.0
#    definition : a short musical composition with words
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('write', False) -> write.v.02 : 0.0
#    definition : communicate or express by writing
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.25 / positive
#  75%|███████▌  | 15/20 [03:35<01:11, 14.37s/it]
# ####### Tweet 14 #######
#
# Jonathan Kozol is the leading author on educational advocacy and social equality. He will be on campus Wednesday,... http://t.co/nteU8d3w
#  -> Jonathan Kozol is the leading author on educational advocacy and social equality. He will be on campus Wednesday,...
#
# ['Jonathan', 'Kozol', 'is', 'the', 'leading', 'author', 'on', 'educational', 'advocacy', 'and', 'social', 'equality', '.', 'He', 'will', 'be', 'on', 'campus', 'Wednesday', ',', '...']
#
# [('Jonathan', Synset('jonathan.n.01')), ('Kozol', None), ('is', None), ('the', None), ('leading', Synset('leave.v.07')), ('author', Synset('writer.n.01')), ('on', None), ('educational', None), ('advocacy', Synset('advocacy.n.01')), ('and', None), ('social', None), ('equality', Synset('equality.n.02')), ('.', None), ('He', None), ('will', None), ('be', None), ('on', None), ('campus', Synset('campus.n.01')), ('Wednesday', Synset('wednesday.n.01')), (',', None), ('...', None)]
#
# [('Jonathan', False), ('Kozol', False), ('is', False), ('the', False), ('leading', False), ('author', False), ('on', False), ('educational', False), ('advocacy', False), ('and', False), ('social', False), ('equality', False), ('.', False), ('He', False), ('will', False), ('be', False), ('on', False), ('campus', False), ('Wednesday', False), (',', False), ('...', False)]
#
#    ('Jonathan', False) -> jonathan.n.01 : 0.0
#    definition : red late-ripening apple; primarily eaten raw
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('leading', False) -> leave.v.07 : 0.0
#    definition : have as a result or residue
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('author', False) -> writer.n.01 : 0.0
#    definition : writes (books or stories or articles or the like) professionally (for pay)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('advocacy', False) -> advocacy.n.01 : 0.0
#    definition : active support of an idea or cause etc.; especially the act of pleading or arguing for something
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('equality', False) -> equality.n.02 : 0.0
#    definition : a state of being essentially equal or equivalent; equally balanced
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('campus', False) -> campus.n.01 : 0.0
#    definition : a field on which the buildings of a university are situated
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Wednesday', False) -> wednesday.n.01 : 0.0
#    definition : the fourth day of the week; the third working day
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.0 / neutral
#  80%|████████  | 16/20 [03:40<00:55, 13.78s/it]
# ####### Tweet 15 #######
#
# @nurinqistinaa @hannahban4na That's the 1st.2nd: Nadia &amp; Mysa about Mysa break dgn Adam. 3rd: this bullshit thingy -.-
#  -> That's the st.2nd: Nadia &amp; Mysa about Mysa break dgn Adam. rd: this bullshit thingy -.-
#
# ['That', "'s", 'the', 'st.2nd', ':', 'Nadia', '&', 'amp', ';', 'Mysa', 'about', 'Mysa', 'break', 'dgn', 'Adam', '.', 'rd', ':', 'this', 'bullshit', 'thingy', '-.-']
#
# [('That', None), ("'s", None), ('the', None), ('st.2nd', None), (':', None), ('Nadia', None), ('&', None), ('amp', Synset('adenosine_monophosphate.n.01')), (';', None), ('Mysa', None), ('about', None), ('Mysa', None), ('break', Synset('pause.n.01')), ('dgn', None), ('Adam', Synset('adam.n.03')), ('.', None), ('rd', None), (':', None), ('this', None), ('bullshit', Synset('bullshit.n.01')), ('thingy', None), ('-.-', None)]
#
# [('That', False), ("'s", False), ('the', False), ('st.2nd', False), (':', False), ('Nadia', False), ('&', False), ('amp', False), (';', False), ('Mysa', False), ('about', False), ('Mysa', False), ('break', False), ('dgn', False), ('Adam', False), ('.', False), ('rd', False), (':', False), ('this', False), ('bullshit', False), ('thingy', False), ('-.-', False)]
#
#    ('amp', False) -> adenosine_monophosphate.n.01 : 0.125
#    definition : a nucleotide found in muscle cells and important in metabolism; reversibly convertible to ADP and ATP
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('break', False) -> pause.n.01 : 0.125
#    definition : a time interval during which there is a temporary cessation of something
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('Adam', False) -> adam.n.03 : 0.0
#    definition : street names for methylenedioxymethamphetamine
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('bullshit', False) -> bullshit.n.01 : -0.375
#    definition : obscene words for unacceptable behavior
#    pos score : 0.0
#    neg score : 0.375
#    obj score : 0.625
#
#   TOTAL score = -0.125 / negative
#  85%|████████▌ | 17/20 [03:46<00:39, 13.29s/it]
# ####### Tweet 16 #######
#
# Thanks to all those who joined UYSA and the University of Utah in celebrating Youth Soccer Month last Saturday,... http://t.co/39jQBGV8
#  -> Thanks to all those who joined UYSA and the University of Utah in celebrating Youth Soccer Month last Saturday,...
#
# ['Thanks', 'to', 'all', 'those', 'who', 'joined', 'UYSA', 'and', 'the', 'University', 'of', 'Utah', 'in', 'celebrating', 'Youth', 'Soccer', 'Month', 'last', 'Saturday', ',', '...']
#
# [('Thanks', Synset('thanks.n.01')), ('to', None), ('all', None), ('those', None), ('who', None), ('joined', Synset('join.v.04')), ('UYSA', None), ('and', None), ('the', None), ('University', Synset('university.n.02')), ('of', None), ('Utah', Synset('utah.n.01')), ('in', None), ('celebrating', Synset('celebrate.v.02')), ('Youth', Synset('young_person.n.01')), ('Soccer', Synset('soccer.n.01')), ('Month', Synset('calendar_month.n.01')), ('last', None), ('Saturday', Synset('saturday.n.01')), (',', None), ('...', None)]
#
# [('Thanks', False), ('to', False), ('all', False), ('those', False), ('who', False), ('joined', False), ('UYSA', False), ('and', False), ('the', False), ('University', False), ('of', False), ('Utah', False), ('in', False), ('celebrating', False), ('Youth', False), ('Soccer', False), ('Month', False), ('last', False), ('Saturday', False), (',', False), ('...', False)]
#
#    ('Thanks', False) -> thanks.n.01 : 0.125
#    definition : an acknowledgment of appreciation
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('joined', False) -> join.v.04 : 0.0
#    definition : make contact or come together
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('University', False) -> university.n.02 : 0.0
#    definition : establishment where a seat of higher learning is housed, including administrative and living quarters as well as facilities for research and teaching
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Utah', False) -> utah.n.01 : 0.0
#    definition : a state in the western United States; settled in 1847 by Mormons led by Brigham Young
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('celebrating', False) -> celebrate.v.02 : 0.0
#    definition : have a celebration
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Youth', False) -> young_person.n.01 : 0.0
#    definition : a young person (especially a young man or boy)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Soccer', False) -> soccer.n.01 : 0.0
#    definition : a football game in which two teams of 11 players try to kick or head a ball into the opponents' goal
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Month', False) -> calendar_month.n.01 : 0.0
#    definition : one of the twelve divisions of the calendar year
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Saturday', False) -> saturday.n.01 : 0.0
#    definition : the seventh and last day of the week; observed as the Sabbath by Jews and some Christians
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.125 / positive
#  90%|█████████ | 18/20 [04:02<00:26, 13.47s/it]
# ####### Tweet 17 #######
#
# @pkollar Well it was either that or watch you play Raccoon City, so.. I think I may have won?
#  -> Well it was either that or watch you play Raccoon City, so.. I think I may have won?
#
# ['Well', 'it', 'was', 'either', 'that', 'or', 'watch', 'you', 'play', 'Raccoon', 'City', ',', 'so..', 'I', 'think', 'I', 'may', 'have', 'won', '?']
#
# [('Well', None), ('it', None), ('was', None), ('either', None), ('that', None), ('or', None), ('watch', Synset('watch.v.01')), ('you', None), ('play', Synset('play.v.01')), ('Raccoon', Synset('raccoon.n.02')), ('City', Synset('city.n.01')), (',', None), ('so..', None), ('I', None), ('think', Synset('think.v.03')), ('I', None), ('may', Synset('whitethorn.n.01')), ('have', None), ('won', Synset('gain.v.05')), ('?', None)]
#
# [('Well', False), ('it', False), ('was', False), ('either', False), ('that', False), ('or', False), ('watch', False), ('you', False), ('play', False), ('Raccoon', False), ('City', False), (',', False), ('so..', False), ('I', False), ('think', False), ('I', False), ('may', False), ('have', False), ('won', False), ('?', False)]
#
#    ('watch', False) -> watch.v.01 : 0.125
#    definition : look attentively
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('play', False) -> play.v.01 : 0.0
#    definition : participate in games or sport
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Raccoon', False) -> raccoon.n.02 : 0.0
#    definition : an omnivorous nocturnal mammal native to North America and Central America
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('City', False) -> city.n.01 : 0.0
#    definition : a large and densely populated urban area; may include several independent administrative districts
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('think', False) -> think.v.03 : 0.0
#    definition : use or exercise the mind or one's power of reason in order to make inferences, decisions, or arrive at a solution or judgments
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('may', False) -> whitethorn.n.01 : 0.0
#    definition : thorny Eurasian shrub of small tree having dense clusters of white to scarlet flowers followed by deep red berries; established as an escape in eastern North America
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('won', False) -> gain.v.05 : 0.25
#    definition : obtain advantages, such as points, etc.
#    pos score : 0.25
#    neg score : 0.0
#    obj score : 0.75
#
#   TOTAL score = 0.375 / positive
#  95%|█████████▌| 19/20 [04:22<00:13, 13.82s/it]
# ####### Tweet 18 #######
#
# Day 1 at the SoCal College Fair @ Pomona Fairplex--1st person to get to our booth &amp; say "your story matters" wins something special! #doit
#  -> Day at the SoCal College Fair Pomona Fairplex--1st person to get to our booth &amp; say "your story matters" wins something special!
#
# ['Day', 'at', 'the', 'SoCal', 'College', 'Fair', 'Pomona', 'Fairplex', '--', '1st', 'person', 'to', 'get', 'to', 'our', 'booth', '&', 'amp', ';', 'say', '``', 'your', 'story', 'matters', "''", 'wins', 'something', 'special', '!']
#
# [('Day', Synset('day.n.04')), ('at', None), ('the', None), ('SoCal', None), ('College', Synset('college.n.02')), ('Fair', Synset('carnival.n.03')), ('Pomona', None), ('Fairplex', None), ('--', None), ('1st', None), ('person', Synset('person.n.01')), ('to', None), ('get', Synset('get.v.01')), ('to', None), ('our', None), ('booth', Synset('booth.n.04')), ('&', None), ('amp', Synset('adenosine_monophosphate.n.01')), (';', None), ('say', Synset('state.v.01')), ('``', None), ('your', None), ('story', Synset('history.n.02')), ('matters', Synset('matter.n.03')), ("''", None), ('wins', Synset('winnings.n.01')), ('something', None), ('special', None), ('!', None)]
#
# [('Day', False), ('at', False), ('the', False), ('SoCal', False), ('College', False), ('Fair', False), ('Pomona', False), ('Fairplex', False), ('--', False), ('1st', False), ('person', False), ('to', False), ('get', False), ('to', False), ('our', False), ('booth', False), ('&', False), ('amp', False), (';', False), ('say', False), ('``', False), ('your', False), ('story', False), ('matters', False), ("''", False), ('wins', False), ('something', False), ('special', False), ('!', False)]
#
#    ('Day', False) -> day.n.04 : 0.0
#    definition : the time after sunrise and before sunset while it is light outside
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('College', False) -> college.n.02 : 0.0
#    definition : an institution of higher education created to educate and grant degrees; often a part of a university
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Fair', False) -> carnival.n.03 : 0.0
#    definition : a traveling show; having sideshows and rides and games of skill etc.
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('person', False) -> person.n.01 : 0.0
#    definition : a human being
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('get', False) -> get.v.01 : 0.125
#    definition : come into the possession of something concrete or abstract
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('booth', False) -> booth.n.04 : 0.0
#    definition : a small shop at a fair; for selling goods or entertainment
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('amp', False) -> adenosine_monophosphate.n.01 : 0.125
#    definition : a nucleotide found in muscle cells and important in metabolism; reversibly convertible to ADP and ATP
#    pos score : 0.125
#    neg score : 0.0
#    obj score : 0.875
#
#    ('say', False) -> state.v.01 : 0.0
#    definition : express in words
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('story', False) -> history.n.02 : 0.0
#    definition : a record or narrative description of past events
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('matters', False) -> matter.n.03 : 0.0
#    definition : that which has mass and occupies space
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('wins', False) -> winnings.n.01 : 0.0
#    definition : something won (especially money)
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#   TOTAL score = 0.25 / positive
# 100%|██████████| 20/20 [04:38<00:00, 13.95s/it]
# ####### Tweet 19 #######
#
# De La Soul's First Serve project with Live Band debuts this Thu 18th in Meeting House Square, ONRA supports on MPC  http://t.co/DN2SfycQ!!!
#  -> De La Soul's First Serve project with Live Band debuts this Thu th in Meeting House Square, ONRA supports on MPC !!!
#
# ['De', 'La', 'Soul', "'s", 'First', 'Serve', 'project', 'with', 'Live', 'Band', 'debuts', 'this', 'Thu', 'th', 'in', 'Meeting', 'House', 'Square', ',', 'ONRA', 'supports', 'on', 'MPC', '!', '!', '!']
#
# [('De', Synset('delaware.n.04')), ('La', Synset('louisiana.n.01')), ('Soul', Synset('person.n.01')), ("'s", None), ('First', Synset('first.n.01')), ('Serve', Synset('serve.n.01')), ('project', Synset('undertaking.n.01')), ('with', None), ('Live', None), ('Band', Synset('set.n.05')), ('debuts', Synset('debut.v.01')), ('this', None), ('Thu', None), ('th', Synset('thursday.n.01')), ('in', None), ('Meeting', Synset('meeting.n.01')), ('House', Synset('firm.n.01')), ('Square', Synset('public_square.n.01')), (',', None), ('ONRA', None), ('supports', Synset('support.v.01')), ('on', None), ('MPC', None), ('!', None), ('!', None), ('!', None)]
#
# [('De', False), ('La', False), ('Soul', False), ("'s", False), ('First', False), ('Serve', False), ('project', False), ('with', False), ('Live', False), ('Band', False), ('debuts', False), ('this', False), ('Thu', False), ('th', False), ('in', False), ('Meeting', False), ('House', False), ('Square', False), (',', False), ('ONRA', False), ('supports', False), ('on', False), ('MPC', False), ('!', False), ('!', False), ('!', False)]
#
#    ('De', False) -> delaware.n.04 : 0.0
#    definition : a Mid-Atlantic state; one of the original 13 colonies
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('La', False) -> louisiana.n.01 : 0.0
#    definition : a state in southern United States on the Gulf of Mexico; one of the Confederate states during the American Civil War
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Soul', False) -> person.n.01 : 0.0
#    definition : a human being
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('First', False) -> first.n.01 : 0.0
#    definition : the first or highest in an ordering or series
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Serve', False) -> serve.n.01 : 0.0
#    definition : (sports) a stroke that puts the ball in play
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('project', False) -> undertaking.n.01 : 0.0
#    definition : any piece of work that is undertaken or attempted
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Band', False) -> set.n.05 : 0.0
#    definition : an unofficial association of people or groups
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('debuts', False) -> debut.v.01 : 0.0
#    definition : present for the first time to the public
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('th', False) -> thursday.n.01 : 0.0
#    definition : the fifth day of the week; the fourth working day
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Meeting', False) -> meeting.n.01 : 0.0
#    definition : a formally arranged gathering
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('House', False) -> firm.n.01 : 0.0
#    definition : the members of a business organization that owns or operates one or more establishments
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('Square', False) -> public_square.n.01 : 0.0
#    definition : an open area at the meeting of two or more streets
#    pos score : 0.0
#    neg score : 0.0
#    obj score : 1.0
#
#    ('supports', False) -> support.v.01 : 0.125
#    definition : give moral or psychological support, aid, or courage to
#    pos score : 0.25
#    neg score : 0.125
#    obj score : 0.625
#
#   TOTAL score = 0.125 / neutral

# %% [markdown]
# ### ** Comparing different WSD methods

# %%
tmp_list = disambiguate('I went to the bank to deposit my money')
for item in tmp_list:
    print(item)
    if item[1]:
        print("    : " + item[1].definition())
    print("")
# Out:
# ('I', None)
#
# ('went', Synset('run_low.v.01'))
#     : to be spent or finished
#
# ('to', None)
#
# ('the', None)
#
# ('bank', Synset('bank.n.09'))
#     : a building in which the business of banking transacted
#
# ('to', None)
#
# ('deposit', Synset('deposit.v.02'))
#     : put into a bank account
#
# ('my', None)
#
# ('money', Synset('money.n.03'))
#     : the official currency issued by a government or national bank

# %% [markdown]
# ### Among similarity options, 'res' seems to do the best.

# %%
for so in ['lch', 'res', 'jcn', 'lin', 'path', 'wup']:
    print("-- " + so + " --")
    tmp_list = disambiguate('I went to the bank to deposit my money', max_similarity, similarity_option=so)
    for item in tmp_list:
        print(item)
        if item[1]:
            print("    : " + item[1].definition())
    print("")
# Out:
# -- lch --
# ('I', None)
# ('went', Synset('travel.v.01'))
#     : change location; move, travel, or proceed, also metaphorically
# ('to', None)
# ('the', None)
# ('bank', Synset('savings_bank.n.02'))
#     : a container (usually with a slot in the top) for keeping money at home
# ('to', None)
# ('deposit', Synset('deposit.v.02'))
#     : put into a bank account
# ('my', None)
# ('money', Synset('money.n.03'))
#     : the official currency issued by a government or national bank
#
# -- res --
# ('I', None)
# ('went', Synset('travel.v.01'))
#     : change location; move, travel, or proceed, also metaphorically
# ('to', None)
# ('the', None)
# ('bank', Synset('depository_financial_institution.n.01'))
#     : a financial institution that accepts deposits and channels the money into lending activities
# ('to', None)
# ('deposit', Synset('situate.v.02'))
#     : put (something somewhere) firmly
# ('my', None)
# ('money', Synset('money.n.01'))
#     : the most common medium of exchange; functions as legal tender
#
# -- jcn --
# ('I', None)
# ('went', Synset('travel.v.01'))
#     : change location; move, travel, or proceed, also metaphorically
# ('to', None)
# ('the', None)
# ('bank', Synset('savings_bank.n.02'))
#     : a container (usually with a slot in the top) for keeping money at home
# ('to', None)
# ('deposit', Synset('deposit.v.02'))
#     : put into a bank account
# ('my', None)
# ('money', Synset('money.n.03'))
#     : the official currency issued by a government or national bank
#
# -- lin --
# ('I', None)
# ('went', Synset('travel.v.01'))
#     : change location; move, travel, or proceed, also metaphorically
# ('to', None)
# ('the', None)
# ('bank', Synset('savings_bank.n.02'))
#     : a container (usually with a slot in the top) for keeping money at home
# ('to', None)
# ('deposit', Synset('deposit.v.02'))
#     : put into a bank account
# ('my', None)
# ('money', Synset('money.n.03'))
#     : the official currency issued by a government or national bank
#
# -- path --
# ('I', None)
# ('went', Synset('travel.v.01'))
#     : change location; move, travel, or proceed, also metaphorically
# ('to', None)
# ('the', None)
# ('bank', None)
# ('to', None)
# ('deposit', Synset('deposit.v.02'))
#     : put into a bank account
# ('my', None)
# ('money', None)
#
# -- wup --
# ('I', None)
# ('went', Synset('travel.v.01'))
#     : change location; move, travel, or proceed, also metaphorically
# ('to', None)
# ('the', None)
# ('bank', None)
# ('to', None)
# ('deposit', Synset('deposit.v.02'))
#     : put into a bank account
# ('my', None)
# ('money', None)

# %% [markdown]
# ### Among 'lesk', 'cosine' lesk does the best.

# %%
i=0
for method in [simple_lesk, original_lesk, adapted_lesk, cosine_lesk]:
    i += 1
    print("--" + str(i))
    tmp_list = disambiguate('I went to the bank to deposit my money', method)
    for item in tmp_list:
        print(item)
        if item[1]:
            print("    : " + item[1].definition())
    print("")
# Out:
# --1
# ('I', None)
# ('went', Synset('run_low.v.01'))
#     : to be spent or finished
# ('to', None)
# ('the', None)
# ('bank', Synset('bank.n.09'))
#     : a building in which the business of banking transacted
# ('to', None)
# ('deposit', Synset('deposit.v.02'))
#     : put into a bank account
# ('my', None)
# ('money', Synset('money.n.03'))
#     : the official currency issued by a government or national bank
#
# --2
# ('I', None)
# ('went', Synset('proceed.v.04'))
#     : follow a certain course
# ('to', None)
# ('the', None)
# ('bank', Synset('bank.v.04'))
#     : act as the banker in a game or in gambling
# ('to', None)
# ('deposit', Synset('depository.n.01'))
#     : a facility where things can be deposited for storage or safekeeping
# ('my', None)
# ('money', Synset('money.n.02'))
#     : wealth reckoned in terms of money
#
# --3
# ('I', None)
# ('went', Synset('run_low.v.01'))
#     : to be spent or finished
# ('to', None)
# ('the', None)
# ('bank', Synset('bank.n.09'))
#     : a building in which the business of banking transacted
# ('to', None)
# ('deposit', Synset('deposit.v.02'))
#     : put into a bank account
# ('my', None)
# ('money', Synset('money.n.03'))
#     : the official currency issued by a government or national bank
#
# --4
# ('I', None)
# ('went', Synset('go.v.02'))
#     : follow a procedure or take a course
# ('to', None)
# ('the', None)
# ('bank', Synset('depository_financial_institution.n.01'))
#     : a financial institution that accepts deposits and channels the money into lending activities
# ('to', None)
# ('deposit', Synset('situate.v.02'))
#     : put (something somewhere) firmly
# ('my', None)
# ('money', Synset('money.n.02'))
#     : wealth reckoned in terms of money

# %% [markdown]
# ### Too many bad examples of sentiment scoring using Built-in SentiWordNet
#
# e.g.
#
# great.n.01 : 0.0
#
# party.n.01 : 0.0
#
# excite.v.01 : -0.125

# %%
swn.senti_synset(wn.synset('good.a.01').name()).neg_score()
# Out:
# 0.0

# %%
wn.synset('good.a.01').definition()
# Out:
# 'having desirable or positive qualities especially those suitable for a thing specified'

# %% [markdown]
# ### REF: Simply using a Built-in Sentiment Classifier
#
# nltk.sentiment.util.demo_liu_hu_lexicon(sentence, plot=False)[source]
# nltk.sentiment.vader.SentimentIntensityAnalyzer(lexicon_file='sentiment/vader_lexicon.zip/vader_lexicon/vader_lexicon.txt')[source]

# %% [markdown]
# ### REF: WordNet corpus provides the distance value inbetween synsets, but it's based on hypernym relationship.
#
# synset1.path_similarity(synset2): Return a score denoting how similar two word senses are, based on the shortest path that connects the senses in the is-a (hypernym/hypnoym) taxonomy.
#
# synset1.res_similarity(synset2, ic): Resnik Similarity: Return a score denoting how similar two word senses are, based on the Information Content (IC) of the Least Common Subsumer (most specific ancestor node).
#
# synset1.wup_similarity(synset2): Wu-Palmer Similarity: Return a score denoting how similar two word senses are, based on the depth of the two senses in the taxonomy and that of their Least Common Subsumer (most specific ancestor node).
#
# synset1.res_similarity(synset2, ic): Resnik Similarity: Return a score denoting how similar two word senses are, based on the Information Content (IC) of the Least Common Subsumer (most specific ancestor node).
#
# synset1.jcn_similarity(synset2, ic): Jiang-Conrath Similarity Return a score denoting how similar two word senses are, based on the Information Content (IC) of the Least Common Subsumer (most specific ancestor node) and that of the two input Synsets.
#
# synset1.lin_similarity(synset2, ic): Lin Similarity: Return a score denoting how similar two word senses are, based on the Information Content (IC) of the Least Common Subsumer (most specific ancestor node) and that of the two input Synsets.

# %% [markdown]
# ### Also, we could use built-in Bing Liu lexicon based sentiment analysis

# %%
nltk.sentiment.util.demo_liu_hu_lexicon(tweets[0], plot=True)
# Out:
# Positive
# /Users/kaka/tm3-env/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### Or, built-in Vader classifier

# %%
vader_analyzer = nltk.sentiment.vader.SentimentIntensityAnalyzer(lexicon_file='sentiment/vader_lexicon.zip/vader_lexicon/vader_lexicon.txt')

# %%
vader_analyzer.polarity_scores(tweets[0])
# Out:
# {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0}

# %%
nltk.sentiment.util.demo_vader_instance(tweets[0])
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
nltk.sentiment.vader.allcap_differential("this song is really AWESOME!!!")
# Out:
# True

# %%
nltk.sentiment.vader.allcap_differential("AWESOME")
# Out:
# False

# %%
nltk.sentiment.util.demo_vader_tweets()
# Out:
# Loaded 2061 tweets
# Loaded 5000 tweets
# Loaded 4072 tweets
# Loaded 5000 tweets
# Accuracy: 0.86
# F-measure [neg]: 0.851063829787234
# F-measure [pos]: 0.8679245283018868
# Precision [neg]: 0.9090909090909091
# Precision [pos]: 0.8214285714285714
# Recall [neg]: 0.8
# Recall [pos]: 0.92

# %% [markdown]
# ### Built-in negation util is not very good, so we'll implement one.

# %%
nltk.sentiment.util.mark_negation(tweets[0], double_neg_flip=False, shallow=False)
# Out:
# 'dec 21st 2012 will be know not as the end of the world but the Baby Boom! #2012shit'

# %%
pairs = nltk.sentiment.util.pairwise(tweets[0].split(' '))

# %%
for t in pairs:
    print(t)
# Out:
# ('dec', '21st')
# ('21st', '2012')
# ('2012', 'will')
# ('will', 'be')
# ('be', 'know')
# ('know', 'not')
# ('not', 'as')
# ('as', 'the')
# ('the', 'end')
# ('end', 'of')
# ('of', 'the')
# ('the', 'world')
# ('world', 'but')
# ('but', 'the')
# ('the', 'Baby')
# ('Baby', 'Boom!')
# ('Boom!', '#2012shit')

# %% [markdown]
# ## WordNet graphical model used for word sense disambiguation

# %%
lemmas_in_words  = set(i for i in wn.words())

# %% [markdown]
# ### Basic WordNet Graph

# %%
seen = set()
wordnet_graph = nx.Graph(engine='sfdp', pack=True)
for word in tqdm(lemmas_in_words):
    wordnet_graph.add_node(word)
    for dw in wn.synsets(word):
        if not dw in seen:
            seen.add(dw)
            wordnet_graph.add_node(dw.name())
        wordnet_graph.add_edge(dw.name(), word)
# Out:
# 100%|██████████| 147306/147306 [00:56<00:00, 2615.64it/s]

# %%
path = './wordnet_graph.p'
nx.write_gpickle(wordnet_graph, path)

# %% [markdown]
# ### Cleanedup version

# %%
# new cleaned wordnet graph

wordnet_graph_cleaned = nx.Graph(engine='sfdp', pack=True)

for word in tqdm(lemmas_in_words):
    wordnet_graph_cleaned.add_node(word)

for word in tqdm(lemmas_in_words):
    nb_list = [k for m in [n for n in wordnet_graph.neighbors(word)] for k in wordnet_graph.neighbors(m)]    
    for nb in nb_list:
        if wordnet_graph_cleaned.has_edge(word, nb) == False:
            wordnet_graph_cleaned.add_edge(word, nb)
# Out:
# 100%|██████████| 147306/147306 [00:00<00:00, 455169.48it/s]
# 100%|██████████| 147306/147306 [00:02<00:00, 71664.42it/s]

# %%
ps = [p for p in nx.all_shortest_paths(wordnet_graph_cleaned, 'good', 'bad')]

# %%
for word in ps:
    print(word)
# Out:
# ['good', 'well', 'swelled', 'bigger', 'bad']
# ['good', 'sounder', 'heavy', 'bigger', 'bad']
# ['good', 'sound', 'heavy', 'bigger', 'bad']
# ['good', 'well', 'swelled', 'big', 'bad']
# ['good', 'sounder', 'heavy', 'big', 'bad']
# ['good', 'sound', 'heavy', 'big', 'bad']

# %% [markdown]
# ### Chekcing words near 'good'

# %%
ncc_good = nx.node_connected_component(wordnet_graph_cleaned, 'good')

# %%
# check words near 'good'
distance = 2
good_words = []
for word in tqdm(ncc_good):
    if nx.shortest_path_length(wordnet_graph_cleaned, 'good', word) <= distance:
        good_words.append(word)
# Out:
# 100%|██████████| 32011/32011 [00:06<00:00, 5296.57it/s]

# %%
len(good_words)
# Out:
# 311

# %%
subg_good = nx.Graph(wordnet_graph_cleaned.subgraph(good_words), engine = 'sfdp')

# %%
pos = graphviz_layout(subg_good)

plt.figure(figsize=(20, 20)) 

nx.draw_networkx_nodes(subg_good,pos,node_size=100,node_color='b',alpha=0.4)
nx.draw_networkx_edges(subg_good,pos,alpha=0.4,node_size=0,width=3,edge_color='m')
nx.draw_networkx_labels(subg_good,pos,fontsize=6)
plt.show()

# %% [markdown]
# ## Instead, we decided to build a graph using synsets.

# %% [markdown]
# #### In the paper, they created a graph based on paths between actual lemmas.
# #### However, we're going to try a graphical model using only synset because they provide more accurate(diambiguated) sense for any sentence.

# %%
synset_list = list(wn.all_synsets())

# %%
wn.synset('dog.n.02').lemmas()
# Out:
# [Lemma('frump.n.01.frump'), Lemma('frump.n.01.dog')]

# %%
wordnet_graph_synset = nx.Graph(engine='sfdp', pack=True)

seen = set()
for ss in tqdm(synset_list):
    wordnet_graph_synset.add_node(ss.name())
    for lm in ss.lemmas():
        _lm = lm.similar_tos()
        if not _lm in seen:
            seen.add(_lm)
            wordnet_graph_synset.add_node(_lm)
        wordnet_graph_synset.add_edge(_lm, ss.name())
# Out:
# 100%|██████████| 117659/117659 [00:01<00:00, 99051.41it/s]

# %%
wordnet_graph_synset.size()
# Out:
# 117659

# %%
wordnet_graph_synset_cleaned = wordnet_graph_synset

'''
# new cleaned wordnet SYNSET graph
wordnet_graph_synset_cleaned = nx.Graph(engine='sfdp', pack=True)

for ss in tqdm(synset_list):
    wordnet_graph_synset_cleaned.add_node(ss.name())

for ss in tqdm(synset_list):
    nb_list = [k for m in [n for n in wordnet_graph_synset.neighbors(ss.name())] for k in wordnet_graph_synset.neighbors(m)]    
    for nb in nb_list:
        if wordnet_graph_synset_cleaned.has_edge(ss.name(), nb) == False:
            wordnet_graph_synset_cleaned.add_edge(ss.name(), nb)
'''
# Out:
# "\n# new cleaned wordnet SYNSET graph\nwordnet_graph_synset_cleaned = nx.Graph(engine='sfdp', pack=True)\n\nfor ss in tqdm(synset_list):\n    wordnet_graph_synset_cleaned.add_node(ss.name())\n\nfor ss in tqdm(synset_list):\n    nb_list = [k for m in [n for n in wordnet_graph_synset.neighbors(ss.name())] for k in wordnet_graph_synset.neighbors(m)]    \n    for nb in nb_list:\n        if wordnet_graph_synset_cleaned.has_edge(ss.name(), nb) == False:\n            wordnet_graph_synset_cleaned.add_edge(ss.name(), nb)\n"

# %% [markdown]
# ### Suggested approach to build a synset definition based graph

# %%
wordnet_graph_synset_relation = nx.Graph(engine='sfdp', pack=True)

seen = set()
for ss in tqdm(synset_list):
    wordnet_graph_synset_relation.add_node(ss.name())
    for lm in ss.lemmas():
        _lm = lm.similar_tos()
        if not _lm in seen:
            seen.add(_lm)
            wordnet_graph_synset_relation.add_node(_lm)
        wordnet_graph_synset_relation.add_edge(_lm, ss.name())

# %% [markdown]
# ### Chekcing synsets near 'good.a.01'

# %%
wn.synset('good.a.01').lemmas()[0].synset()
# wn.synset('amazing.s.02').lemmas()[1].synset().name()
# Out:
# Synset('good.a.01')

# %%
ncc_good_a_01 = nx.node_connected_component(wordnet_graph_synset_cleaned, 'good.a.01')
distance = 2
good_synsets = []
for ss in tqdm(ncc_good_a_01):
    if nx.shortest_path_length(wordnet_graph_synset_cleaned, 'good.a.01', ss) <= distance:
        good_synsets.append(ss)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 4691.62it/s]

# %%
good_synsets
# Out:
# ['good.a.01']

# %%
subg_good = nx.Graph(wordnet_graph_synset_cleaned.subgraph(good_synsets), engine = 'sfdp')

# %%
pos = graphviz_layout(subg_good)

plt.figure(figsize=(20, 20)) 

nx.draw_networkx_nodes(subg_good,pos,node_size=100,node_color='b',alpha=0.4)
nx.draw_networkx_edges(subg_good,pos,alpha=0.4,node_size=0,width=3,edge_color='m')
nx.draw_networkx_labels(subg_good,pos,fontsize=6)
plt.show()

# %% [markdown]
# ### Distance estimated from positive/negative words

# %%
def DIST_word(word, graph, p_word='good', n_word='bad'):
    if graph.has_node(word) and graph.has_node(p_word) and graph.has_node(n_word):

        if nx.has_path(graph, p_word, n_word):
            p_n = nx.shortest_path_length(graph, p_word, n_word)
        else:
            print('No path between '+ n_word + ' and ' + p_word)
            return 0
        
        if nx.has_path(graph, word, n_word):
            n_w = nx.shortest_path_length(graph, n_word, word)
        else:
            return 0
        
        if nx.has_path(graph, word, p_word):
            p_w = nx.shortest_path_length(graph, p_word, word)
        else:
            return 0

        print('distance to '+ n_word + ' : ' + str(n_w))
        print('distance to '+ p_word + ' : ' + str(p_w))
        print('distance between '+ n_word + ' and ' + p_word + ' : ' + str(p_n))
        return (n_w - p_w) / p_n
    else :
        print(word + ' is not in the graph.')
        return 0

# %%
DIST_word('happy', wordnet_graph_cleaned)
# Out:
# distance to bad : 7
# distance to good : 6
# distance between bad and good : 4
# 0.25

# %%
DIST_word('sad', wordnet_graph_cleaned)
# Out:
# distance to bad : 2
# distance to good : 5
# distance between bad and good : 4
# -0.75

# %%
DIST_word('fuck', wordnet_graph_cleaned)
# Out:
# distance to bad : 5
# distance to good : 3
# distance between bad and good : 4
# 0.5

# %%
DIST_word('awkward', wordnet_graph_cleaned)
# Out:
# distance to bad : 4
# distance to good : 5
# distance between bad and good : 4
# -0.25

# %% [markdown]
# ### Distance estimated from positive/negative SYNSETS

# %%
wn.synset('good.a.01').definition()
# Out:
# 'having desirable or positive qualities especially those suitable for a thing specified'

# %%
wn.synset('bad.a.01').definition()
# Out:
# 'having undesirable or negative qualities'

# %%
def DIST_synset(ss, graph, p_ss='good.a.01', n_ss='bad.a.01'):
    _ss = ss
#     print(wn.synset(ss).definition())
    if graph.has_node(_ss) and graph.has_node(p_ss) and graph.has_node(n_ss):

        if nx.has_path(graph, p_ss, n_ss):
            p_n = nx.shortest_path_length(graph, p_ss, n_ss)
        else:
#             print('No path between '+ p_ss + ' and ' + n_ss)
            return 0
        
        if nx.has_path(graph, _ss, n_ss):
            n_w = nx.shortest_path_length(graph, n_ss, _ss)
        else:
            return 0
        
        if nx.has_path(graph, _ss, p_ss):
            p_w = nx.shortest_path_length(graph, p_ss, _ss)
        else:
            return 0

#         print('distance to '+ n_ss + ' : ' + str(n_w))
#         print('distance to '+ p_ss + ' : ' + str(p_w))
#         print('distance between '+ n_ss + ' and ' + p_ss + ' : ' + str(p_n))
        return (n_w - p_w) / p_n
    else :
        print(_ss + ' is not in the graph.')
        return 0

# %%
DIST_synset('happy.a.01', wordnet_graph_synset_cleaned)
# Out:
# enjoying or showing or marked by joy or pleasure
# distance to bad.a.01 : 10
# distance to good.a.01 : 9
# distance between bad.a.01 and good.a.01 : 5
# 0.2

# %%
DIST_synset('sad.a.01', wordnet_graph_synset_cleaned)
# Out:
# experiencing or showing sorrow or unhappiness
# distance to bad.a.01 : 3
# distance to good.a.01 : 6
# distance between bad.a.01 and good.a.01 : 5
# -0.6

# %%
wn.synsets('awkward')
# Out:
# [Synset('awkward.s.01'),
#  Synset('awkward.a.02'),
#  Synset('awkward.s.03'),
#  Synset('awkward.s.04'),
#  Synset('awkward.s.05'),
#  Synset('awkward.s.06')]

# %%
DIST_synset('awkward.a.02', wordnet_graph_synset)
# Out:
# lacking grace or skill in manner or movement or performance
# distance to bad.a.01 : 14
# distance to good.a.01 : 16
# distance between bad.a.01 and good.a.01 : 10
# -0.2

# %%
wn.synsets('fucking')
# Out:
# [Synset('fuck.n.01'),
#  Synset('sleep_together.v.01'),
#  Synset('bally.s.01'),
#  Synset('fucking.r.01')]

# %%
DIST_synset('fucking.r.01', wordnet_graph_synset)
# Out:
# intensifier, very colloquial
# distance to bad.a.01 : 12
# distance to good.a.01 : 10
# distance between bad.a.01 and good.a.01 : 10
# 0.2

# %%
DIST_synset('fucking.r.01', wordnet_graph_synset_cleaned)
# Out:
# intensifier, very colloquial
# distance to bad.a.01 : 6
# distance to good.a.01 : 5
# distance between bad.a.01 and good.a.01 : 5
# 0.2

# %% [markdown]
# ## (3) Using graphical model for disambiguation

# %%
wn.synsets('better-known')
# Out:
# [Synset('better-known.s.01')]

# %%
wn.synset('positive.a.01').definition()
# Out:
# 'characterized by or displaying affirmation or acceptance or certainty etc.'

# %%
wn.synset('good.a.01').lemmas()[0].antonyms()[0]
# Out:
# Lemma('bad.a.01.bad')

# %%
wn.synset('positive.a.01').definition()
# Out:
# 'positive.a.01'

# %% [markdown]
# ### Using opinion_lexicon (Bing Liu sentiment lexicons)
#
# #### A list of positive and negative opinion words or sentiment words for English.
#
#  from nltk.corpus import opinion_lexicon
#
#  opinion_lexicon.words()[:4]
#
#
# ['2-faced', '2-faces', 'abnormal', 'abolish']
#
#
# #### The OpinionLexiconCorpusReader also provides shortcuts to retrieve positive/negative words:
#
#  opinion_lexicon.negative()[:4]
#
#
# ['2-faced', '2-faces', 'abnormal', 'abolish']
#
#
# #### Note that words from words() method in opinion_lexicon are sorted by file id, not alphabetically:
#
#  opinion_lexicon.words()[0:10]
#
#
# ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably',
# 'abominate', 'abomination', 'abort', 'aborted']
#
#
# sorted(opinion_lexicon.words())[0:10]
#
#
# ['2-faced', '2-faces', 'a+', 'abnormal', 'abolish', 'abominable', 'abominably',
# 'abominate', 'abomination', 'abort']

# %%
from nltk.corpus import opinion_lexicon

# %%
len(opinion_lexicon.positive())
# Out:
# 2006

# %%
len(opinion_lexicon.negative())
# Out:
# 4783

# %%
len(opinion_lexicon.positive())
# Out:
# 2006

# %%
## Prepare all antonyms for every word in opinion lexicon

bingliu_pos_synset_pair_list = []
for word in opinion_lexicon.positive():
    for i in wn.synsets(word):
        # if i.pos() in ['a', 's', 'r', 'v']: # no nouns
        for j in i.lemmas(): 
            if j.antonyms(): 
                bingliu_pos_synset_pair_list.append((j.synset().name(), j.antonyms()[0].synset().name()))

bingliu_neg_synset_pair_list = []
for word in opinion_lexicon.negative():
    for i in wn.synsets(word):
        # if i.pos() in ['a', 's', 'r', 'v']: # no nouns
        for j in i.lemmas(): 
            if j.antonyms(): 
                ## NOTE that we put antonyms first
                bingliu_neg_synset_pair_list.append((j.antonyms()[0].synset().name(), j.synset().name()))

# %%
len(bingliu_pos_synset_pair_list)
# Out:
# 1284

# %%
len(bingliu_neg_synset_pair_list)
# Out:
# 1868

# %%
[('good.a.01', 'bad.a.01')]

# %%
def GetSentenceSentiScore(tweet_sentence, label, graph, cmp_ss_pair_lists):
    cleaned_tweet = p.clean(tweet_sentence)
    replaced_tweet = replace_word(cleaned_tweet)
    
    ## Can replace this by using other WSD options (different Lesk algorithms / similarity options)
    
#     da_token_pair_list = disambiguate(replaced_tweet, max_similarity, similarity_option='res')
    da_token_pair_list = disambiguate(replaced_tweet, cosine_lesk)
    
    da_token_list = []
    for pair in da_token_pair_list:
        da_token_list.append(pair[0])
    
    tokens, token_pair_list = negate(da_token_list)
    
#     print("####### Tweet #######" )
#     print("")
#     print(tweet_sentence)
#     print(" -> " + replaced_tweet)
#     print("")
#     print(da_token_list)
#     print("") 
#     print(da_token_pair_list)
#     print("") 
#     print(token_pair_list)
#     print("")     
    
    assert(len(da_token_pair_list) == len(token_pair_list))
    
    score = 0
    for j in range(len(da_token_pair_list)):
        curr_neg = False
        if token_pair_list[j][1]:
#             print("negated : " + token_pair_list[j][0])
            curr_neg = True
        
        curr_ss = da_token_pair_list[j][1]
        curr_score = 0
        if curr_ss:
            for cmp_ss_pair_list in cmp_ss_pair_lists:
                for cmp_ss_pair in cmp_ss_pair_list:
                    curr_score += DIST_synset(curr_ss.name(), graph, cmp_ss_pair[0], cmp_ss_pair[1])
                curr_score /= len(cmp_ss_pair_list)
            
            if curr_neg:
                curr_score *= -1
                
#             print("   " + str(token_pair_list[j]) + " -> " + curr_ss.name() + " : " + str(curr_score))
#             print("   definition : " + wn.synset(curr_ss.name()).definition())
#             print("   score from graph : " + str(curr_score))
#             print("")
            score += curr_score            
            
        else:
            continue
    print("Tweet " + str(i) + " : TOTAL score = " + str(score) + " / " + label)
#     print("")
    
    return score

# %%
import time

# %%
## testing a few tweets
for i in range(1):
    start = time.time()
    GetSentenceSentiScore(tweets[i], labels[i], wordnet_graph_synset_cleaned, [[('good.a.01', 'bad.a.01')]])
    print(time.time()-start)
# Out:
# Tweet 0 : TOTAL score = -0.39999999999999997 / neutral
#
# 0.0672299861907959

# %%
SentiGraphFeature = []
for i in range(2):
    start = time.time()
    SentiGraphFeature.append(GetSentenceSentiScore(tweets[i], labels[i], wordnet_graph_synset_cleaned, 
                                                   [bingliu_pos_synset_pair_list]))
    print(time.time()-start)
# Out:
# Tweet 0 : TOTAL score = -0.08112802522849243 / neutral
#
# 5.087244272232056
# Tweet 1 : TOTAL score = 0.03303083857990398 / negative
#
# 5.940690279006958

# %%
## custom word set
custom_words_set = ['good', 'awesome', 'beautiful', 'boom', 'celebrate', 'charm', 'cheerful', 
                    'clean', 'confident', 'convenient', 'cozy']

custom_synset_pair_list = []

for word in custom_words_set:
    for i in wn.synsets(word):
        # if i.pos() in ['a', 's', 'r', 'v']: # no nouns
        for j in i.lemmas(): 
            if j.antonyms(): 
                ## NOTE that we put antonyms first
                custom_synset_pair_list.append((j.antonyms()[0].synset().name(), j.synset().name()))

# %%
len(tweets)
# Out:
# 11692

# %%
SentiGraphFeature = []
for i in tqdm(range(len(tweets))):
    start = time.time()
    SentiGraphFeature.append(GetSentenceSentiScore(tweets[i], labels[i], wordnet_graph_synset_cleaned, 
                                                   [bingliu_pos_synset_pair_list]))
    print(time.time()-start)
# Out:
#   0%|          | 1/11692 [00:04<14:16:12,  4.39s/it]
# Tweet 0 : TOTAL score = -0.08112802522849243 / neutral
#
# 4.3941216468811035
#   0%|          | 2/11692 [00:10<16:48:39,  5.18s/it]
# Tweet 1 : TOTAL score = 0.03303083857990398 / negative
#
# 5.959338426589966
#   0%|          | 3/11692 [00:16<17:40:31,  5.44s/it]
# Tweet 2 : TOTAL score = 0.16699048182693038 / positive
#
# 5.976454734802246
#   0%|          | 4/11692 [00:21<17:04:14,  5.26s/it]
# Tweet 3 : TOTAL score = 0.13994315220950743 / positive
#
# 4.700043201446533
#   0%|          | 5/11692 [00:25<16:44:34,  5.16s/it]
# Tweet 4 : TOTAL score = 0.17999839162222345 / positive
#
# 4.7547547817230225
#   0%|          | 6/11692 [00:31<17:10:17,  5.29s/it]
# Tweet 5 : TOTAL score = -0.02574157842849435 / negative
#
# 5.951657056808472
#   0%|          | 7/11692 [00:34<15:55:35,  4.91s/it]
# Tweet 6 : TOTAL score = 0.09362449163851046 / neutral
#
# 2.6074557304382324
#   0%|          | 8/11692 [00:40<16:37:54,  5.12s/it]
# Tweet 7 : TOTAL score = 0.2278645290327535 / neutral
#
# 6.648107051849365
#   0%|          | 9/11692 [00:46<16:45:26,  5.16s/it]
# Tweet 8 : TOTAL score = 0.2011886132213235 / negative
#
# 5.476255416870117
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-658d8e7e7756> in <module>()
#       3     start = time.time()
#       4     SentiGraphFeature.append(GetSentenceSentiScore(tweets[i], labels[i], wordnet_graph_synset_cleaned,
# ----> 5                                                    [bingliu_pos_synset_pair_list]))
#       6     print(time.time()-start)
#
# <ipython-input-59-90cdc0ef7062> in GetSentenceSentiScore(tweet_sentence, label, graph, cmp_ss_pair_lists)
#      40             for cmp_ss_pair_list in cmp_ss_pair_lists:
#      41                 for cmp_ss_pair in cmp_ss_pair_list:
# ---> 42                     curr_score += DIST_synset(curr_ss.name(), graph, cmp_ss_pair[0], cmp_ss_pair[1])
#      43                 curr_score /= len(cmp_ss_pair_list)
#      44
#
# <ipython-input-56-aeeeb952f3c7> in DIST_synset(ss, graph, p_ss, n_ss)
#      10             return 0
#      11
# ---> 12         if nx.has_path(graph, _ss, n_ss):
#      13             n_w = nx.shortest_path_length(graph, n_ss, _ss)
#      14         else:
#
# ~/tm3-env/lib/python3.5/site-packages/networkx/algorithms/shortest_paths/generic.py in has_path(G, source, target)
#      38     """
#      39     try:
# ---> 40         sp = nx.shortest_path(G, source, target)
#      41     except nx.NetworkXNoPath:
#      42         return False
#
# ~/tm3-env/lib/python3.5/site-packages/networkx/algorithms/shortest_paths/generic.py in shortest_path(G, source, target, weight)
#     140             # Find shortest source-target path.
#     141             if weight is None:
# --> 142                 paths = nx.bidirectional_shortest_path(G, source, target)
#     143             else:
#     144                 paths = nx.dijkstra_path(G, source, target, weight)
#
# ~/tm3-env/lib/python3.5/site-packages/networkx/algorithms/shortest_paths/unweighted.py in bidirectional_shortest_path(G, source, target)
#     224
#     225     # call helper to do the real work
# --> 226     results = _bidirectional_pred_succ(G, source, target)
#     227     pred, succ, w = results
#     228
#
# ~/tm3-env/lib/python3.5/site-packages/networkx/algorithms/shortest_paths/unweighted.py in _bidirectional_pred_succ(G, source, target)
#     277                 for w in Gsucc[v]:
#     278                     if w not in pred:
# --> 279                         forward_fringe.append(w)
#     280                         pred[w] = v
#     281                     if w in succ:  # path found
#
# KeyboardInterrupt:
